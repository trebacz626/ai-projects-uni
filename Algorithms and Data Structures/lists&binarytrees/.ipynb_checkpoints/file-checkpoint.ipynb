# %%
from random import randint,sample
import sys
import matplotlib.pyplot as plt
import numpy as np
import time 
import math
import random
import string
sys.setrecursionlimit(10**9)
plt.rcParams['figure.figsize'] = (10.0, 6.0)

# %%
class Node:
    def __init__(self,surname,firstname,index):
        self.surname = surname
        self.firstname = firstname
        self.index = index
        self.next_node = None

        
class SortedList:
    def __init__(self):
        self.next_node = None
    def add(self,element):
        new_node = Node(element[0],element[1],element[2])
        if not self.next_node:
            self.next_node = new_node
            return
        node = self
        while(node.next_node and node.next_node.index < new_node.index):
            node = node.next_node
        temp_node = node.next_node
        node.next_node = new_node
        new_node.next_node = temp_node
    
    def get(self,index):
        node = self.next_node
        while(node and node.index < index):
            node = node.next_node
        if(node and node.index == index):
            return node
        else:
            return None
    def delete(self,index):
        node = self
        while(node.next_node and node.next_node.index < index):
            node = node.next_node
        if(node.next_node and node.next_node.index == index):
            temp = node.next_node
            node.next_node = node.next_node.next_node#
            del(temp)
        else:
            raise BaseException("Element not found")
    def print_all(self):
        node = self.next_node
        while(node):
            print(node.surname+" "+node.firstname+" "+str(node.index))
            node = node.next_node

# %%
class TreeNode:
    def __init__(self,surname, firstname, index,left,right):
        self.left=left
        self.right=right
        self.surname = surname
        self.firstname = firstname
        self.index = index
    def print_me(self,level):
        print('-'.join(["-" for i in range(level)])+self.surname+self.firstname+str(self.index))
        if self.left:
            print('-'.join(["-" for i in range(level)])+'left')
            self.left.print_me(level+1)
        if self.right:
            print('-'.join(["-" for i in range(level)])+'right')
            self.right.print_me(level+1)
    def count(self):
        suma = 0
        if self.left:
            suma+=self.left.count()
        if self.right:
            suma+=self.right.count()
        return suma+1
    def delete(self,index):
        if self.index == index:
            if self.left and self.right:
                next_node = self.find_smallest(self.right)
                self.index = next_node.index
                self.surname = next_node.surname
                self.firstname = next_node.surname
            elif self.left:
                return self.left
            elif self.right:
                return self.right
            else:
                return None
        elif index < self.index:
            if not self.left:
                raise BaseException("Index not found")
            self.left = self.left.delete(index)
        else:
            if not self.right:
                raise BaseException("Index not found")
            self.right = self.right.delete(index)
        return self
    def find_smallest(self,node):
        parent =self
        child = node
        if not node.left:
            parent.right = node.right
            return node
        while node.left:
            parent = node
            node =node.left
        parent.left = node.right
        return node

class Tree:
    def __init__(self):
        self.root = None
    def add(self,element):
        new_node = TreeNode(element[0],element[1],element[2],None,None);
        if not self.root:
            self.root = new_node
            return
        cur_node = self.root
        while True:
            if new_node.index < cur_node.index:
                if cur_node.left:
                    cur_node=cur_node.left
                else:
                    cur_node.left = new_node
                    break
            else:
                if cur_node.right:
                    cur_node = cur_node.right                
                else:
                    cur_node.right = new_node
                    break
    def get(self,index):
        cur_node = self.root
        while cur_node:
            if index < cur_node.index:
                cur_node = cur_node.left
            elif index > cur_node.index:
                cur_node = cur_node.right
            else:
                return cur_node
        raise BaseException("No node with this id")
    def delete(self,index):
        self.root=self.root.delete(index)


    def get_min_node(self,node):
        parent = node
        while parent.left and parent.left.left:
            parent = parent.left
        if parent.left:
            temp = parent.left
            parent.left = None
            return temp
        return parent
        
    def print_all(self):
        if self.root:
            self.root.print_me(0)
        else:
            print("Empty tree")
    def count(self):
        if not self.root:
            return 0
        return self.root.count()

# %%
def prepare_student(idx):
    return [''.join([random.choice(string.ascii_letters) for _ in range(12)]),''.join([random.choice(string.ascii_letters) for _ in range(12)]),idx]

def prepare_students(amount):
    return [prepare_student(idx) for idx in range(1000000,1000000+amount)]

def prepare_test_dataset(maximum,jump=1):
    X = [amount for amount in range(1,maximum,jump)]
    Y = [prepare_students(amount) for amount in X]
    return X,Y

# %%
prepare_test_dataset(102,5)
# Out:
# ([1,
#   6,
#   11,
#   16,
#   21,
#   26,
#   31,
#   36,
#   41,
#   46,
#   51,
#   56,
#   61,
#   66,
#   71,
#   76,
#   81,
#   86,
#   91,
#   96,
#   101],
#  [[['uVtnkaaMchBc', 'OJJMNfZPEfSp', 1000000]],
#   [['lmxXQCExkBad', 'ijEqMXpEXRnh', 1000000],
#    ['YPkwLubEQrCr', 'lYZoZvQvKNBp', 1000001],
#    ['CRDTTJWJyauL', 'cMnSQzQkzqDT', 1000002],
#    ['LsGuAQVbvEfL', 'hHuLrepqmjBH', 1000003],
#    ['xXyICMFLpBac', 'wRYJOxOQrlyQ', 1000004],
#    ['yHGuCYImyzbB', 'VOqRZrNiPDXz', 1000005]],
#   [['rheTMgezSuAA', 'osPOmPinjhcC', 1000000],
#    ['AWrfWsQbsZks', 'FvKpsbEtZERH', 1000001],
#    ['VWBtuYbSgbLL', 'kkPVgYHUeAwC', 1000002],
#    ['RrDxTmRkgauc', 'LYIYxLMQQxpR', 1000003],
#    ['oMlqmPsZBAmv', 'ltfLQAPXoJyD', 1000004],
#    ['XYdmfKVayMgl', 'NdRTnUauwVKl', 1000005],
#    ['FZwqcGoirefD', 'VpzEmgeTZvxi', 1000006],
#    ['cobGibtYVlbF', 'lObALIbOIFzz', 1000007],
#    ['gAtmLwupiEDI', 'mNGpdQAAMTNP', 1000008],
#    ['xvTInKusqmzr', 'NYrFuGbBVnmW', 1000009],
#    ['pBWJULCIhIjb', 'PVxAcjeYWaOM', 1000010]],
#   [['NbnLIwPKOKYA', 'fAdJOQsjPANL', 1000000],
#    ['VqKgYCumhIZi', 'mgLtObhCdXWA', 1000001],
#    ['knHaXhYvSjpI', 'EYYPUsJxeEYB', 1000002],
#    ['JlEirLaRVKTo', 'ASTMnmFWGyGu', 1000003],
#    ['IyCZrDHqRMXO', 'ykUeELHcsnQn', 1000004],
#    ['ZnehplKNWnES', 'pesvDHmAWJoO', 1000005],
#    ['lLWZVwLFyrXn', 'VmYjQaPytaGf', 1000006],
#    ['mxIwCyfVleNP', 'fjgkvzUNJVaT', 1000007],
#    ['EvilYbtKmiWL', 'nCKRzXrzXPJv', 1000008],
#    ['GnzjXZZhiXji', 'GhTXgfbaiYmp', 1000009],
#    ['NShpppwobRyi', 'XClbOhXoUJrZ', 1000010],
#    ['MxMqZFqIqyRQ', 'jgYwgymbTomr', 1000011],
#    ['xjghUtBqZolK', 'XhmckuDgfDJj', 1000012],
#    ['eUAOrfFJWSYZ', 'xuRZZmlHexFK', 1000013],
#    ['rlPQpPofIMry', 'YLoeZrPJUClK', 1000014],
#    ['FiypbqqhNYqW', 'iLwWAulUoQOx', 1000015]],
#   [['FVAgpRRNxXiK', 'qPUEzYCctIyi', 1000000],
#    ['gaqCUYCjHHdo', 'evdTUXgoUPFn', 1000001],
#    ['iEFCHvLkWFBt', 'pMzmvoWKBLaU', 1000002],
#    ['bgXXtrVKgIQT', 'QRMLJhOTagxr', 1000003],
#    ['MQhvBYSCPRFg', 'kpCtoNSGHPmj', 1000004],
#    ['FVQbKGCbRqIW', 'DRepbLNFgpmq', 1000005],
#    ['KgnIWtYpLjBj', 'dicyNOJKMmkf', 1000006],
#    ['HrhWIQegjnnA', 'HZVxCCSMQOHL', 1000007],
#    ['vSaVZhKarYIw', 'GRlKmrjTSUzc', 1000008],
#    ['UHYCtGNmJBXJ', 'ttRCryLPUzeb', 1000009],
#    ['zwfLCOUcNVXr', 'PlIXecPCCaNO', 1000010],
#    ['hZveIRnPKCou', 'zZjfYzuvFvgK', 1000011],
#    ['FvICpyhYDJOt', 'DYrgFKWYIVnu', 1000012],
#    ['ZfbvyGCwkvYy', 'VVzBcaBvSyZk', 1000013],
#    ['FMXxLhLjcOub', 'vmIBiRVxTwAA', 1000014],
#    ['sMDrYyGWxkpm', 'OhNrtRLeTHhJ', 1000015],
#    ['DTvHASSstyQv', 'lmzOocNinhym', 1000016],
#    ['ZsMbOmdddRvo', 'ntwifCLKNUeX', 1000017],
#    ['OQSHZqzPyxep', 'DfbYmcTdWDVk', 1000018],
#    ['JHbEHCeteuUg', 'eqLRxyCMLxQB', 1000019],
#    ['oZKfiKJkauwk', 'mgjfAAEKbirl', 1000020]],
#   [['XHBYNVAnKbKs', 'ZOmihCVMsaCu', 1000000],
#    ['iEWqaDLyHsEH', 'VXkSJLKxDqgx', 1000001],
#    ['BiSuikcDpjpy', 'mWCVtXzoNEmM', 1000002],
#    ['IzWPBmRaWwqp', 'ERTmLrIDLqwb', 1000003],
#    ['vVrnZocprJLV', 'nhHWRsDvDQFt', 1000004],
#    ['DpFRVWmbUvbs', 'XcaCyHsJeEWd', 1000005],
#    ['qgYcoeaIEvaX', 'PbmpEWezqDNr', 1000006],
#    ['FUjlKojdcbRZ', 'YBVHQBpixjDq', 1000007],
#    ['QRzeBQdJPKVA', 'EyYGNsmrlaKw', 1000008],
#    ['LQYpLOjRVjau', 'FuFfCUwBQTmv', 1000009],
#    ['ApTtVuwJDZEj', 'iohwaLEPfiBU', 1000010],
#    ['ncgGIrpKxOjZ', 'kABojAjgfMpP', 1000011],
#    ['mdOiYHxngsVU', 'bqLXfQrENbxK', 1000012],
#    ['COytUcrOsKvo', 'EpADeEsUaBFl', 1000013],
#    ['eetBUfRXHcDG', 'BjTipmndqJbD', 1000014],
#    ['NnfdiKdfQYvx', 'RCgjvwPdQxFr', 1000015],
#    ['XjpfeoXJoEQO', 'VCRVAgXycDzb', 1000016],
#    ['cuNQnSCtaYgX', 'tGZsMHojDjDF', 1000017],
#    ['QidNtsLRqQkp', 'JqPseBnrHxmX', 1000018],
#    ['nnKnJYwaeZSd', 'AzqolAghXMbp', 1000019],
#    ['akuTwrqkEPzw', 'aJQsYntuxcVD', 1000020],
#    ['NWlmVtSuZMrU', 'kLSiKmzhAvqD', 1000021],
#    ['faymcLNJhbFg', 'QIlCHajYsFjv', 1000022],
#    ['AUuwgTRIkLXf', 'PjUWgfHrZqSa', 1000023],
#    ['LmhFMwNISKaC', 'VzIffoSFRTmO', 1000024],
#    ['uBrveMbkEMWM', 'hIbOFYOgRdCI', 1000025]],
#   [['rcqVrtWhXDLD', 'hnSorCuuPSti', 1000000],
#    ['fTmPGJQnEewC', 'PGhtyCMhlnkN', 1000001],
#    ['PYimvZaKEnIq', 'DcTziLYZuOMi', 1000002],
#    ['YgnnEwYObali', 'RdDxTEMpCmXt', 1000003],
#    ['OmpNoqWHfXOy', 'nYmFLkjGwnmG', 1000004],
#    ['trwDAIvJwcOW', 'NelvYcDLleCc', 1000005],
#    ['ugenwrTkxIxT', 'MJeVAjUTBexQ', 1000006],
#    ['nSwAGWYfiWOp', 'ROLOvYAiFAJK', 1000007],
#    ['TpWGPSDAnUcI', 'xaVJGspsImhk', 1000008],
#    ['aWdeemzUuYXI', 'iQafzQaIkMle', 1000009],
#    ['zKOejngGkDTp', 'hRHDqQwIJVGW', 1000010],
#    ['FgzVpZmnmbHb', 'nZZiMLQXxeVD', 1000011],
#    ['HRUBIXvbdOLr', 'ksZBXOdfCJjV', 1000012],
#    ['NilBYkhBGpkv', 'jrhMwbMmRtUA', 1000013],
#    ['RtiAfxLHMnxW', 'EJNJjEBQaqKZ', 1000014],
#    ['acmbdlqkugTR', 'TBrUxkNPqumM', 1000015],
#    ['ohowksNhmvsH', 'wxfcgVuclhfl', 1000016],
#    ['LJPGyqqSPuLE', 'GVoMeSsZIOWS', 1000017],
#    ['qYsOInarVexv', 'NZbEibiWrWIP', 1000018],
#    ['yROizDtYsYWV', 'kEDRzwedjZmU', 1000019],
#    ['fRcHhLWymFsO', 'dLzhKrUVRzcx', 1000020],
#    ['womehcBhgLlU', 'tasyggyCJUoZ', 1000021],
#    ['yFfmzQoKxVjz', 'yIVslBmAOfag', 1000022],
#    ['ZbxOyogBeVIp', 'HvaiCJkppVDh', 1000023],
#    ['FCbUsAIiGWjw', 'aTtaudpCHgcL', 1000024],
#    ['NGrUBGCOSwTE', 'TsPtzUQWqqBw', 1000025],
#    ['nCEgwzkQhAIN', 'YBmurruZwPoe', 1000026],
#    ['DsqPcTUJCKnm', 'VBtqUlZpzffu', 1000027],
#    ['JVNJFxIhHSmx', 'eUfUtghPezqT', 1000028],
#    ['wAaiAvlTBofL', 'BuwUAqJXRXBf', 1000029],
#    ['tgZCYoxLfqKJ', 'nocQpJuIFydM', 1000030]],
#   [['olnDqGnsgqwE', 'KWeDAaBENpal', 1000000],
#    ['WawaOqvKaqot', 'zofblxYvfOaR', 1000001],
#    ['EdyCzIZRTqDX', 'HfPRMWiCalVh', 1000002],
#    ['oKDldzmgaGhV', 'ZDJvOLytmOtn', 1000003],
#    ['pwUIeKTpskAP', 'WyRZCjgBMuTX', 1000004],
#    ['ZjWRmOCMKEbm', 'MBRWEhKRoLAm', 1000005],
#    ['UTeqtyiRaUVY', 'VRsPXIOITsTb', 1000006],
#    ['gqCOzHfCGruI', 'nvIOnVmfZLRX', 1000007],
#    ['ZScByYOtLVHU', 'qaqNXbGIeOfJ', 1000008],
#    ['erhlDyGXndEF', 'DeHXtbktjEko', 1000009],
#    ['rhajRvkksWON', 'XhvTcElAgDAg', 1000010],
#    ['pqdQzuBMzMzl', 'bTaNcggwkzhP', 1000011],
#    ['KlidEBNRZCoX', 'xdoUHELtqjzG', 1000012],
#    ['VaWJoZccjlOB', 'EmbpVyALtYUa', 1000013],
#    ['BlfjPTFRNQKI', 'rsrtEBjHQAmg', 1000014],
#    ['hefxsYbZsNhb', 'vEPdSumZActa', 1000015],
#    ['tuvTESrmACsg', 'QMwNPUKcDMEd', 1000016],
#    ['bGfykvwcTuum', 'FrStYyPjTcAw', 1000017],
#    ['kSYpeRpJizBm', 'rECQehwIBXir', 1000018],
#    ['oTLnRaqRNRxN', 'iPGQnpRYNfFx', 1000019],
#    ['DbHheyBIOhwW', 'TaQIjaGRnOTT', 1000020],
#    ['PVSpRiNDNVsP', 'EdFrSUrVFVIn', 1000021],
#    ['ydzDIrVwHGTV', 'mBlFQrKMYSeE', 1000022],
#    ['McCyoUZmDCkL', 'HAzLUUMZpGuS', 1000023],
#    ['IEaYDgHLNmnp', 'QtmNTHbFtNyE', 1000024],
#    ['kRScGMiNialK', 'mXCPvZwQRujF', 1000025],
#    ['vzRfIObodWdA', 'TjrRwUrowcVQ', 1000026],
#    ['vrciKaDhkJcL', 'uZapLKYANcqL', 1000027],
#    ['RmUDTluAZAVp', 'OEWxVimkCyhb', 1000028],
#    ['lZNwYQYUTHIr', 'NmOROrGacbvG', 1000029],
#    ['EglZvWDRkIRF', 'HwVZWcJpaeMk', 1000030],
#    ['tUzaNoHSxVet', 'nJHeQYCKPYCh', 1000031],
#    ['QTbCRKuZUpuV', 'ryeqfEwzYOnt', 1000032],
#    ['KZZXGiKkigRW', 'SXNTvNtqnUjr', 1000033],
#    ['tordNtgsBkXK', 'rQuKGNuznjVg', 1000034],
#    ['zaFxdMZIzeSm', 'ilwuVfSlLSKQ', 1000035]],
#   [['JMXQCjJeDijO', 'uLDkzoNoRwib', 1000000],
#    ['ilbnZRtWkKyr', 'rLeAUnmJcujU', 1000001],
#    ['xOBOMOeCAwPi', 'ChLsEqwbiYFJ', 1000002],
#    ['jtalYMhowgSb', 'dwSbXkmtMKmi', 1000003],
#    ['YULJUTPBEVna', 'BqFEkHgFIfxp', 1000004],
#    ['JsdbFroEOfsa', 'lRyalcggOnLp', 1000005],
#    ['GtePKLHZDfXH', 'PSdkzybTbzZt', 1000006],
#    ['zMyYmCFhjaHn', 'dVJhLdpxbCLQ', 1000007],
#    ['JioMtdqWIOPZ', 'zNdHJWazWdIj', 1000008],
#    ['sQEBSyinxYQM', 'UOuSBsJSeckl', 1000009],
#    ['iwruAwyQaBmc', 'SjwxNunwwkyZ', 1000010],
#    ['nmvoXbsSYime', 'xVtmqipLNive', 1000011],
#    ['zsUqFEbtSgwj', 'ZTirAEAwTERQ', 1000012],
#    ['uNRHAlqcapvC', 'CvPZyAnxjoRY', 1000013],
#    ['ZdfBeORcGLrE', 'XvDnaHeHCxjG', 1000014],
#    ['nrQNDzzjXazJ', 'dKHRJvTkxvNJ', 1000015],
#    ['rrkwqlDyInva', 'knVZiffUQLHs', 1000016],
#    ['KzkdMnQViMln', 'RBqWEDfdKyGt', 1000017],
#    ['iOKhpEgxdwCl', 'kLUNWHFploLS', 1000018],
#    ['ZUnDhvPxuyka', 'QmNoGvhflrfq', 1000019],
#    ['DbXGlpMiYRJH', 'clywhtSzWBnl', 1000020],
#    ['rziWSIALXHKC', 'TpxQHZcIypyM', 1000021],
#    ['xuvabimkUIGa', 'RrVDgoNnpBVP', 1000022],
#    ['mNJnpeXGQafw', 'PGWkAfHvzSca', 1000023],
#    ['PnRGMBBaxOwF', 'iycfJVknyISa', 1000024],
#    ['AydgiMgFJAKP', 'eHwnlbHzlrng', 1000025],
#    ['tWWWdNMFWhcA', 'HIGyMOFmHIkl', 1000026],
#    ['cXhNLQcJjBjH', 'hqXkbYXuMACN', 1000027],
#    ['JWTTQoFIedJr', 'TRRNgRjrbYrK', 1000028],
#    ['TqnmFAlatVeV', 'CVADxEfHbAot', 1000029],
#    ['dcgVSageScNE', 'mVCOXuSRYrZb', 1000030],
#    ['xOhKhSNunzmW', 'orOVYQWPbcvP', 1000031],
#    ['vcxmDBZPuIJD', 'zctpXiaycpDF', 1000032],
#    ['DBSoSlakDBpi', 'MwBCTMEGACnR', 1000033],
#    ['hHaIuaTZDrNK', 'EKRFpIlQBRzJ', 1000034],
#    ['HokfuLnHtYjc', 'LgLjBLTrafYf', 1000035],
#    ['uiIYFbAyvjJZ', 'ZamtrqhrgUeS', 1000036],
#    ['ureRjqKKjlJW', 'WnXCdldwqLWK', 1000037],
#    ['PSaFYwohxFXD', 'aROJvcqAmfDH', 1000038],
#    ['uGCdXPiXTyno', 'tBJsuXpEnPCW', 1000039],
#    ['XlRRvrwLCvbR', 'qwFrDPPpKfGH', 1000040]],
#   [['pkWxyxRUvxyk', 'lnKbaHvctSiK', 1000000],
#    ['USrfUvsBneDe', 'gudQxnIjimWn', 1000001],
#    ['LvcsvYZixCZj', 'SthEovhLsXCe', 1000002],
#    ['sFsUXmeQPxnf', 'AvEkHeveRixO', 1000003],
#    ['KxsAvQkAyLZY', 'yeAKWGYHpihf', 1000004],
#    ['wHVxtqJkNjjF', 'mEgQRvxVQnOR', 1000005],
#    ['lSBxnivvuhvL', 'eXfKcmrXaOSE', 1000006],
#    ['gisScGYxoHjo', 'tZqlahprXfxR', 1000007],
#    ['WTOGCBaTkHdv', 'dqQZJLrdDjyj', 1000008],
#    ['FlzRVcPRqUUs', 'cgaehfCISssy', 1000009],
#    ['xcnhBfYzUDdf', 'hIjovpNhzhxU', 1000010],
#    ['SjYaULwUYlfw', 'uQYDwIEccdyu', 1000011],
#    ['rDyLVSBiMjEY', 'afPoJeKRLLMm', 1000012],
#    ['LCcdwjqGzSyM', 'lhMSnvHjdzlX', 1000013],
#    ['hsfWJkYawjPb', 'uPxlXvynthyR', 1000014],
#    ['ddyqrbzUWgXi', 'AkHOJDBqCVhg', 1000015],
#    ['RLaTFAFnCFwI', 'SvOQnRsdPPDw', 1000016],
#    ['EEoiMUyXpPVl', 'RnOlkWBwhxIq', 1000017],
#    ['KJFuKKqfNBhh', 'pJGJoSzRTlVt', 1000018],
#    ['aqGoayseECJT', 'dtdlDPIxpBHR', 1000019],
#    ['OEUSbzOAPGQA', 'AEgevKHSRyMD', 1000020],
#    ['kinaMGHRaaYZ', 'fMjBCFuVNkaV', 1000021],
#    ['vovsUvMBzqHh', 'OYIsdCkODKAz', 1000022],
#    ['NjtrjZhoETSr', 'oVsjmUCdcyME', 1000023],
#    ['kywfiGlOEIoJ', 'wOFHXkjPBGdX', 1000024],
#    ['sUNesOjGTvjK', 'vdxLpzxuTtxq', 1000025],
#    ['QzlmOyGtSICs', 'bwunrfRzHHQQ', 1000026],
#    ['uRFWEtcvRsnK', 'kyUbBSSdUWru', 1000027],
#    ['FoABXwKDZHZn', 'olbezFtmHTCo', 1000028],
#    ['ZbmKsIQNYcGZ', 'xPAmenPpEtaz', 1000029],
#    ['MKHvFFqEmkjZ', 'OmOAYxieBsOc', 1000030],
#    ['uphFMvXYEHgC', 'CbNBmnOinjJv', 1000031],
#    ['ncfohvFVvLha', 'rmUsaJzMCrxb', 1000032],
#    ['tAdNmpwtktjL', 'RJuPQNgojoey', 1000033],
#    ['ZVQOOFZDanmP', 'HKHbMBTvuhpc', 1000034],
#    ['nKCCcFzbjrdO', 'xdezeZEYdPLf', 1000035],
#    ['fIQJyyhfeVYO', 'LgrdVgYYFxvV', 1000036],
#    ['ADbgiBGgiQVQ', 'IUqSeZDmNGYx', 1000037],
#    ['iHZjSZurwHBJ', 'HKAdiEJwVRnQ', 1000038],
#    ['bUxnWjtpJmEz', 'XzCJnBxoMTST', 1000039],
#    ['DXLTsOSMtlhI', 'slBkcZwEEeYL', 1000040],
#    ['KLdZeytDyDtf', 'nWYxNLOtkQyU', 1000041],
#    ['rbbaRnjYodYG', 'NBFwGjHlpdbM', 1000042],
#    ['vWWXnlLySeUa', 'fujfZRhZsXGP', 1000043],
#    ['mDKqiYjAjeOk', 'CFlImhgNzwIC', 1000044],
#    ['VBguSCwIMonj', 'fQTMdPwDqBzq', 1000045]],
#   [['beblKbaGxaAr', 'EpulAtHEZeei', 1000000],
#    ['XwqSrcCggFtr', 'PrlMIKZNwLiA', 1000001],
#    ['mIBYKDseVqXL', 'FZWdURWAmaeW', 1000002],
#    ['zdUAhPdBcCEK', 'AmeNLWshbLLQ', 1000003],
#    ['ukJCROPRMHRy', 'VGuduQLEIqBy', 1000004],
#    ['dkRjaNuWRfUC', 'qAkZhhPWGSip', 1000005],
#    ['iwtqbzUxrIeC', 'YLIBbORHTjMK', 1000006],
#    ['yJRGWwQZfAoI', 'jDcJNdYtIMoD', 1000007],
#    ['zLLOAMBQjpoQ', 'vibDZqudiVQI', 1000008],
#    ['ehmbSflmqbpz', 'opJCWPtCSqYa', 1000009],
#    ['GXerJcYnNoTj', 'hWoLnLQtRjCJ', 1000010],
#    ['yheBBncQORwI', 'ebQWUBZLFIdu', 1000011],
#    ['GkhMcxHvoadu', 'ZBoNrGVkwxxD', 1000012],
#    ['yaPoWpppkMrM', 'TLtoOSViUnaS', 1000013],
#    ['KRzCbKdnerzb', 'LTveooKfCoLL', 1000014],
#    ['odpWTlecbHFK', 'nBKDRxhUPfKu', 1000015],
#    ['HlQoQCTpMPgM', 'IxRHHgTtqCyu', 1000016],
#    ['aRhzclGJmljA', 'inVHWwTaLiYL', 1000017],
#    ['aGwLIqDJgXpe', 'NMjgYVhubRqi', 1000018],
#    ['Gzrxjcdscmtv', 'NKbsgUPFWFna', 1000019],
#    ['ltZWNkGtIqoS', 'OGAtPRtnOYwx', 1000020],
#    ['jdLsSOppAGJt', 'BxjGVMDBmCbZ', 1000021],
#    ['xiVGQERLfKUv', 'XmgYBAtsSCLB', 1000022],
#    ['gjTMuPQvEpbT', 'epFFoidQXbIw', 1000023],
#    ['VMZgfXTzXpAG', 'JMEclHdhpeiH', 1000024],
#    ['HmiPCXDFguOU', 'dePcHyPIjSPC', 1000025],
#    ['amIZoGLfHoTK', 'OIaaLHyfJDuh', 1000026],
#    ['dAtanYdlDDiC', 'VHGJBwJtQSjb', 1000027],
#    ['YPGWzRnUbTvY', 'MrZYfDpOvKpL', 1000028],
#    ['CPMQIQGccmyx', 'gYPNksKagpXf', 1000029],
#    ['brQKqvsoWjYm', 'tBFgeqOguBPO', 1000030],
#    ['SmBFDzMzVRnM', 'PFGzgOxaeZtu', 1000031],
#    ['TMTfJzIEgkfL', 'fdtlwiJbSIxT', 1000032],
#    ['pHiuZOLHcjOG', 'AfcLPUvRKpqw', 1000033],
#    ['ANzhbwRpwZFD', 'pPhGqigpiaIi', 1000034],
#    ['jZdWEOVMyyHo', 'qJYIcsDqDsoc', 1000035],
#    ['iXBMmOmlOvKr', 'NkhIKtTwcFcY', 1000036],
#    ['bJPunNQhfAEs', 'CMjsQYEmwmwn', 1000037],
#    ['uIAAIhYPJAay', 'AdBHlXVXyhAS', 1000038],
#    ['CrGukJRyQoiA', 'gsKpWjHREhCA', 1000039],
#    ['ofYVgsAJFiXL', 'PghndxuVoABw', 1000040],
#    ['PtokFoMzTgqD', 'WjJXjZfMChPH', 1000041],
#    ['wdOtFtcHollu', 'XhLXLQGRxkEX', 1000042],
#    ['jPJZYFxzBbKZ', 'kJuTXJtsWEPC', 1000043],
#    ['hvmTkrLoCOLs', 'cbHwXhiqZQbt', 1000044],
#    ['qAZBUiVcklxb', 'uzNdtghjosdo', 1000045],
#    ['OqQIFZyGqCfM', 'hDzFiQNBuRPZ', 1000046],
#    ['PMnaAWIFqjFb', 'dcReJzGavLSd', 1000047],
#    ['EWvxAXxVFtOK', 'friDoPPfItcd', 1000048],
#    ['gqtZmEUUerLj', 'GTWhQuAujFII', 1000049],
#    ['ASqrPaOsKVlm', 'aLqgLJrmAcTb', 1000050]],
#   [['rlLohpvpYOeE', 'ePGdDbtdtzPr', 1000000],
#    ['dDZSdIPraFnf', 'pUfZSRhgJzqy', 1000001],
#    ['kIFZAAQNflmO', 'fWOeqYnfkVxi', 1000002],
#    ['MVIaSxtfHdMM', 'oudXLhKEgkrv', 1000003],
#    ['YAkUqdGjcQjm', 'nailTMLgzXcK', 1000004],
#    ['dCuBdCbSBnZr', 'SFaQHZYYWdVc', 1000005],
#    ['ucfiJDrqNaLB', 'XNORTLPuwyzL', 1000006],
#    ['fGGsmyvulhBq', 'AbSQuQzOJbAC', 1000007],
#    ['rherTNiwbIEG', 'jHTZIPcqeKbH', 1000008],
#    ['JAaEHLJFtaKq', 'cDhWmLZbdrGk', 1000009],
#    ['GieaWXMQTUCY', 'NFgvteFKoyJf', 1000010],
#    ['XxJZBEjUKsBu', 'USIsAMQQLaNn', 1000011],
#    ['CPUzECjWVwWs', 'RquFCnIIqlnU', 1000012],
#    ['AnAmkiUNbGZf', 'XySzPjiFILFR', 1000013],
#    ['JNhHvBWkwkKk', 'qBZNwYcDVThz', 1000014],
#    ['UmxFFhKXkEdI', 'iGtjhpYoaOvO', 1000015],
#    ['qdpGGGWdkTsv', 'KKPpxjjFFaBJ', 1000016],
#    ['OYUFaUHUXwGK', 'cdidkafWFIUO', 1000017],
#    ['MXCoEnbWsIkR', 'RKgaCJDyaNnZ', 1000018],
#    ['GVrGJoYXjGpi', 'yEhpujvuOHKJ', 1000019],
#    ['OAjlPQWXxSny', 'sIaWSblykoud', 1000020],
#    ['mUyCNvDoUSEm', 'nvpzotVLdJoW', 1000021],
#    ['sPCRFijtpwnV', 'eEEUwQhQhgdK', 1000022],
#    ['eTDOvaxFKRoi', 'TizlNkBPfTUC', 1000023],
#    ['oHaGRrauGfek', 'BOcXEjhSTjKO', 1000024],
#    ['jGJMMJeoybyf', 'dAomgWdOKQtN', 1000025],
#    ['pxAbnyEQdRNp', 'iIHpMKCJGqhb', 1000026],
#    ['CCUjMuERgoEQ', 'UUWxFTIKFdQz', 1000027],
#    ['nWqxGVeCmfLj', 'BoowPLJNkwDi', 1000028],
#    ['EDOzDhGTVXSS', 'vdNJQdogoQhC', 1000029],
#    ['tXKpZcTyekOW', 'yNLirHMogjGE', 1000030],
#    ['QgGWRPeHGaQD', 'rIUDmBfTINVe', 1000031],
#    ['uXEXGumyEUHh', 'augmJdATMimD', 1000032],
#    ['IdWzDvkCrrcB', 'FPvbJZTrUweS', 1000033],
#    ['GlHXLxBDJpcK', 'pfYyVQBCuVIh', 1000034],
#    ['fgcsWlLfQtPA', 'didvfGfaTdXW', 1000035],
#    ['BfUSzRVSqIUq', 'QGQtPSPbzulp', 1000036],
#    ['mGAcsLEgbeYA', 'NcVXBdnkBEGn', 1000037],
#    ['XzwqHqjXEFIy', 'rkVEVoMZhxXW', 1000038],
#    ['HZXFmbGkBAjL', 'MbSUIgnPihMM', 1000039],
#    ['pgbHBuvxfcUf', 'rPWKQUdiDaEt', 1000040],
#    ['oOaLelUjJFlV', 'GRjibJLquPMJ', 1000041],
#    ['lyAkZmZlKxJG', 'qlVFyIGJtbVA', 1000042],
#    ['NFNGzHgpsgVw', 'LPrPNNQJtMIu', 1000043],
#    ['pBXsgOdtjQlA', 'nNnylgYHRZnm', 1000044],
#    ['kjacmxrwSbIr', 'LPmrAcMHFhkB', 1000045],
#    ['sxdpWOBWECEB', 'bHdYUwRnuqAi', 1000046],
#    ['FgMOVwbLxOOJ', 'gCqqcauqbjZK', 1000047],
#    ['WMvYAKdxeoPm', 'RjmmZayYmaCS', 1000048],
#    ['bRZlxCxsFegS', 'bMnHrmxSOSHO', 1000049],
#    ['UUkjhLYRcCUA', 'RpCiywITGCrm', 1000050],
#    ['hGirtpNtNldy', 'nUWbWWbkHrNG', 1000051],
#    ['KkuedRBDAtYv', 'HYZzANlntRiX', 1000052],
#    ['falDkwUuzPwu', 'gTTOwJGNRqoV', 1000053],
#    ['plSCtVMuuziE', 'FRwnyuYxBmtr', 1000054],
#    ['JEZrAhViyePJ', 'LBZcgZjqFSFB', 1000055]],
#   [['dBFfvHIcdEwq', 'xdqKnzQLfyZN', 1000000],
#    ['TPnTVdCnGZYO', 'mVXyIaQKNUNl', 1000001],
#    ['dVhQUCVRqujU', 'DdBpRRTcNenb', 1000002],
#    ['nXSSAssIFQwU', 'FrxACoXtcstX', 1000003],
#    ['SPmTPjycyJzH', 'LzlBrqvQiFGe', 1000004],
#    ['hRUTJEsKPVgN', 'dseZyrtATRWm', 1000005],
#    ['fNyGqchDdRFm', 'oiWtvdGCCTXi', 1000006],
#    ['NAYjlAkaihtV', 'oQwFPvZRssax', 1000007],
#    ['vnuLkCYfLQtx', 'uiObJtjkSzRi', 1000008],
#    ['nMFDPNxsoUKU', 'klSYKIsIlPZg', 1000009],
#    ['KoCfCvKygGNF', 'OrzXAOuHwcRO', 1000010],
#    ['TitjNTrVJZWN', 'eMAtITVOHQyV', 1000011],
#    ['fdvXJDxnhzXT', 'mYgjOoEOHJeS', 1000012],
#    ['rZfgNMMbOgze', 'fNvrujCnpoqG', 1000013],
#    ['uYmUeONyfxeb', 'xrjwjNWcIiqi', 1000014],
#    ['quJlHqTyaCfg', 'cGPACPPhhlRh', 1000015],
#    ['wTuHLtrwdZgW', 'NvmWAjjgTysf', 1000016],
#    ['ypBBBscJMWUZ', 'fNwKnvYKxKCW', 1000017],
#    ['cXijkKDpKYIs', 'qNSLslIBrJxb', 1000018],
#    ['MdjOlFrTMbmV', 'qWursdFJpWtn', 1000019],
#    ['tYRoRlJgTQWF', 'qtwrSHntJMXR', 1000020],
#    ['FxmevOqBDAPO', 'EGOFrLAqMcog', 1000021],
#    ['JUcqDLQpLeIA', 'HvOVKutZPmEO', 1000022],
#    ['ozecJrqOfbcB', 'axheCqFaiUjv', 1000023],
#    ['wzesPoTqdARA', 'fvzKNJHZsmQy', 1000024],
#    ['gufiXoSEVxxM', 'XfSdZYJGaECs', 1000025],
#    ['GAkndJlNAIji', 'CAJiTxgSGCjl', 1000026],
#    ['mLdginaCwmwr', 'wZFXTmPSaqaq', 1000027],
#    ['lpcaWbHZwhzE', 'SEJOiGaCVzqt', 1000028],
#    ['LLbsbuseZTfZ', 'UOkwIjojzKvf', 1000029],
#    ['DjKTVxoYyjUw', 'uULotUHofCWf', 1000030],
#    ['cEDCPprWsKPY', 'pgGpZskkwnio', 1000031],
#    ['lzZHGdoFonsp', 'riwoYlggHYXB', 1000032],
#    ['HfpVQgqoswvQ', 'fyIdYjcYsPds', 1000033],
#    ['gKcxFbpylndJ', 'tNaVQTpRJSCG', 1000034],
#    ['dFNwzzLDUTwd', 'sUkfumSkCmRG', 1000035],
#    ['eBPWhozPdwNb', 'aXlKBsepqHWJ', 1000036],
#    ['OdcVXIIgKpuD', 'SMVyvcRyzSYb', 1000037],
#    ['wQvKEXQZEgRq', 'UfWgdbTcrTQs', 1000038],
#    ['ivtWcjaoQppP', 'UwpDVHxnQZhS', 1000039],
#    ['iZJESODCcPiA', 'zCotdfyrxIZC', 1000040],
#    ['yeLEotroREKj', 'bOqpPzLweWUi', 1000041],
#    ['cjLPxHxTMwVr', 'VQCqcHBVqHnX', 1000042],
#    ['wXjysGgIgMvU', 'LlbuAxSUDjmc', 1000043],
#    ['SBuwIFyGtWLc', 'WznZsOEVnwuD', 1000044],
#    ['YrukypkgCKVE', 'wAkGlhZTjkdG', 1000045],
#    ['hVqchZMePNAR', 'LRSzHRzJCjNZ', 1000046],
#    ['OVjconLMODvY', 'sUEXOpphajau', 1000047],
#    ['cTxuVAzKNxwF', 'uHdZHSUWdMaO', 1000048],
#    ['QDcIcLFtOhty', 'KBTRhFXzgPeg', 1000049],
#    ['CSDGwfINgzfO', 'PZLMASlGxsRw', 1000050],
#    ['kqkzNDysdPVu', 'mxYuPrPwKxiC', 1000051],
#    ['cIwQvqnOUgQu', 'rJxisrCxDiVA', 1000052],
#    ['cTDdlotnVVEx', 'PthDWoHVNiMZ', 1000053],
#    ['OtWZqoMSpmwd', 'ORxSrpgZpaKU', 1000054],
#    ['nHPfgBybfvLi', 'qtBEKJgOPwoT', 1000055],
#    ['qEopfOPoynLV', 'LdbBUeJpCcUc', 1000056],
#    ['frPNpXWuIDTa', 'JzxSFojrlWSF', 1000057],
#    ['rGpkHBaQJhzX', 'eXnzzDRwpqpV', 1000058],
#    ['dpAbOTFmjuOo', 'qNLQZnPjOFmC', 1000059],
#    ['jBGRimRRmWvS', 'zmPtiUUfiPMP', 1000060]],
#   [['uvnZuSIYTzbR', 'nvzrKjQFrLhQ', 1000000],
#    ['QdBGBNYGARTV', 'cTlxKkXIMUxZ', 1000001],
#    ['fuOXnZzjrIrv', 'gMbQqQvwmwFU', 1000002],
#    ['qLfDfJRolxQo', 'QIUijdWlZuNP', 1000003],
#    ['PqJsFxMePRik', 'KhhpOVHcOjEF', 1000004],
#    ['PiTxZIhVgfdH', 'MtheVwRwXfvn', 1000005],
#    ['vgXbBAHcYheu', 'xRPfyQuLZwro', 1000006],
#    ['EtvQdoDaRDiX', 'nTvtuZxZhZlE', 1000007],
#    ['aRspGIyIfQnZ', 'HwVSoludbpOv', 1000008],
#    ['xNJqJiYcGaZJ', 'ZsBJpqkRayuL', 1000009],
#    ['XqegkPHbcdIm', 'qqEoxceVRNQL', 1000010],
#    ['xKHsGofYrTpJ', 'TOUQcjauVgSZ', 1000011],
#    ['IgnQjvsqEevs', 'VQHudKHGeIsj', 1000012],
#    ['xwjxufdYgRbW', 'EiswEuVXliCG', 1000013],
#    ['uWtMwQrvfSMO', 'LhbTqknbTHYL', 1000014],
#    ['YJqvLtdlbFXo', 'eRJoNiYDJLqe', 1000015],
#    ['SdLQlzKKsZUM', 'IuVXuMuOErrR', 1000016],
#    ['aLMuJYnmQlka', 'qwBVzycBVLuK', 1000017],
#    ['kLTaAtRzEuYg', 'FJYdTWdeeTsi', 1000018],
#    ['cuefoNAOWwBa', 'hasUeOylGBUO', 1000019],
#    ['iFnMcOVbQwZq', 'ZeeiXTqpISHD', 1000020],
#    ['OEJUVrzMYRCa', 'yZXdEZAZIFip', 1000021],
#    ['fdAIePAkJjjT', 'gqtLRcAPttAC', 1000022],
#    ['MpSTNdlMmIge', 'jEyHOQnvFzgQ', 1000023],
#    ['UBRAgqLtxzeW', 'HEfqyDUThQHC', 1000024],
#    ['xSHSxRAFkfvN', 'AasHnqaNenfu', 1000025],
#    ['hZbjncCeGjop', 'zzOIWExzuiHs', 1000026],
#    ['cufxFOBDkwPy', 'aTDWPFiejbfQ', 1000027],
#    ['mrhVhyfeYlwx', 'UKDPuRQByhIs', 1000028],
#    ['WGsWXyzTekcN', 'tVYLJwOskiwd', 1000029],
#    ['XGqkHjYMwURD', 'CaXgzGhbSSyB', 1000030],
#    ['NSBdjiYWOwcS', 'jZxiwspXYkeT', 1000031],
#    ['bFoALVmXptEs', 'lKaVomhrtXhv', 1000032],
#    ['aqdPUrmlhwDm', 'xTINLMGVfLvk', 1000033],
#    ['ZZaqZxLLxTHz', 'jtyRNqOrFhxh', 1000034],
#    ['pXIPIuGYBOYV', 'fPnwatTQggwj', 1000035],
#    ['IrgbylyWqfrb', 'LoMvXwcEvAOg', 1000036],
#    ['VqoIXKxzuYKa', 'PyBpEhdQyNec', 1000037],
#    ['mxCiXIbjbTph', 'TlwoDyRWKPfK', 1000038],
#    ['jiFLJnvUHlPa', 'YePZiVfIFozU', 1000039],
#    ['WMozqcoxostA', 'ghPbTiOjUcVL', 1000040],
#    ['sdOliznLYQlq', 'cqclVvOmNVRR', 1000041],
#    ['giYjIHRyagiy', 'xLkSslKtoAls', 1000042],
#    ['UHkYDakaABnm', 'iFOkkzBCAqAx', 1000043],
#    ['wEiamgknNCBu', 'CWTdEtFDuWEA', 1000044],
#    ['htZnbkQGzGAw', 'LEVaqFaXUOpk', 1000045],
#    ['MsnrvWRiXOLW', 'cmcClBlZOvKi', 1000046],
#    ['dtVWUdhjftKW', 'QSXaZytrqRyV', 1000047],
#    ['fsHQCeeNQIhb', 'JlKSeiCfMgxM', 1000048],
#    ['CuGBYXpokMrA', 'HtjqSUozvHjI', 1000049],
#    ['YusbdEXcCTbT', 'fnNctXwKvTQy', 1000050],
#    ['KiOTEubiciZa', 'oUXahtbMIzuk', 1000051],
#    ['mdYeHGySAhrp', 'hqAYxSYddvHj', 1000052],
#    ['xTrGMycKqpqP', 'osmZVhjogvFl', 1000053],
#    ['PYRVBkAFaHAW', 'NfQDUOuTJCyX', 1000054],
#    ['nLnqqQvReyDM', 'MTtibZiFsDYR', 1000055],
#    ['phYxcMrmelVf', 'bSRxZpkUIKOX', 1000056],
#    ['WcmZCpfIoewF', 'aXycVIERyefg', 1000057],
#    ['GJYHwdauYLAU', 'RgEEpIvcJEoB', 1000058],
#    ['nmlZTmpqJqMj', 'nmDsUULfrLfE', 1000059],
#    ['PgsNCfNmArbD', 'mOyyjYrDCXdq', 1000060],
#    ['JRTKqtNNkoMX', 'RJOrdjOdoBzi', 1000061],
#    ['PAObMcFGvIlj', 'AIheUyrFLCnW', 1000062],
#    ['fKXIubOiPIMb', 'ENewBOeNCRhd', 1000063],
#    ['hTeGoVSWyTCH', 'SLoZawLHYktF', 1000064],
#    ['UuEGRHzjpdxk', 'jnynitfwnpjV', 1000065]],
#   [['PboxqGtFmSEc', 'OyLzIeCSdmKN', 1000000],
#    ['aZhtquVOaplD', 'hGQoEzewssPx', 1000001],
#    ['ICcGTTJpfPbC', 'NCOUbVgBcHds', 1000002],
#    ['tyyGKgWXlLrF', 'UVRsNiVMvosP', 1000003],
#    ['uxNvefgSxVTl', 'NZScOyozqtIa', 1000004],
#    ['vnnRDpnKQXzn', 'tZjQJPKikmUI', 1000005],
#    ['PdosFgsqkLUZ', 'xJaqckYIFktH', 1000006],
#    ['AfejAkqFitgd', 'pacsTjZMQdvL', 1000007],
#    ['qKxqEnerAbQs', 'EXNBqfCLRDAd', 1000008],
#    ['bWchWObQTjkS', 'YqJvihiplvrV', 1000009],
#    ['IShrFJqFpqdC', 'TqnitZkQEamB', 1000010],
#    ['bjgmcoCkLxqv', 'QclgvpcnrLIQ', 1000011],
#    ['HeWSzdmoynNS', 'nLOkuiyvbDGv', 1000012],
#    ['ImhupFkWeaRJ', 'RwdyzLgRmIwq', 1000013],
#    ['iwTWCXCuwydn', 'pHllPzBlAnpX', 1000014],
#    ['QCfqnIjQmGAO', 'WnXwKvUrUMAU', 1000015],
#    ['GXAnpKQNYJXk', 'dSFzqcIFHDFu', 1000016],
#    ['LSyDbGqcvGmf', 'spiIIJeuybXo', 1000017],
#    ['xUyoXNYgHzKa', 'lMWedLtCAUwd', 1000018],
#    ['DyIlyZjxvvmo', 'kOiatoMyzPlz', 1000019],
#    ['ynfKfOgVqomX', 'bdysJoQuqnvV', 1000020],
#    ['BUztZETsMajo', 'PapmBJxFkPbp', 1000021],
#    ['QQDbfEkfNIOK', 'DkjPFHcijFHT', 1000022],
#    ['wpuMGPpfcXdE', 'FJxScfmtrJVE', 1000023],
#    ['ZlraSGMlOUxs', 'qBdzbBEmKJht', 1000024],
#    ['TALKMauEixqR', 'pEEvYfACxWBz', 1000025],
#    ['mOGGGaOnwcDT', 'nRmNfszCFVLD', 1000026],
#    ['AvRzGKPfmLDZ', 'dQuKVHNbXqxc', 1000027],
#    ['WtBsdAzuDWPi', 'qTgPsKWygAcp', 1000028],
#    ['IUMBLdQYHuWm', 'lUVjqewqWoVn', 1000029],
#    ['oOQgxmcuqGSy', 'LTjWFIasrUDd', 1000030],
#    ['WZxMlIlUORSR', 'mtsAGOPsModO', 1000031],
#    ['sWCuYxZXRXCi', 'FBAWlwMwMlgO', 1000032],
#    ['kJmhErFexNjA', 'hezEdjFDBdca', 1000033],
#    ['TyzgadTTgohP', 'FDPWJPXsGaYY', 1000034],
#    ['KVVynlXtEtZF', 'HxSrWrzNAzFQ', 1000035],
#    ['iUZWDbGCPtOy', 'uqqrETToqoKV', 1000036],
#    ['wUubxHjwjSKU', 'eYmlQjPJPqdg', 1000037],
#    ['vivCEkkUNzYW', 'tUSRTbPQMreW', 1000038],
#    ['ZXYsLjSuYVwg', 'wNYQobWBDBFM', 1000039],
#    ['nGCBksTDHZXc', 'DNrBSOhDPCXV', 1000040],
#    ['LRdzTDIzXzoi', 'yVshKCROsNBB', 1000041],
#    ['rrjDphZOdzeI', 'jYhnkLkqwyQr', 1000042],
#    ['zuWsPsVuPWLy', 'GIpGSzqdvYDu', 1000043],
#    ['YzdmdlhfVfZA', 'rIqvYJUGJLQU', 1000044],
#    ['YJPVnkhPchhl', 'QBbWSfGspSzA', 1000045],
#    ['MpAEnRmHtGct', 'nskRyzXaiGjK', 1000046],
#    ['IhBzKBrFCJPV', 'tvZkCbhdGYuI', 1000047],
#    ['zXrbrStvZfzt', 'rFNiEjSmVXcN', 1000048],
#    ['QPojAUnMPmIw', 'TezXxXMJQpKA', 1000049],
#    ['SAAiQZlPJgOY', 'yROWorTtPNSa', 1000050],
#    ['GYitOgiVUazU', 'dRhevxwDeHDb', 1000051],
#    ['raIJlpaGiMOG', 'AUHZvDvusgkX', 1000052],
#    ['ajYQlwawiCqs', 'wNuWNUHXYVPU', 1000053],
#    ['miHotoCyFXuj', 'mcOYwnpXlboY', 1000054],
#    ['gMtrxHfrxQcT', 'EGUrIbYpeURj', 1000055],
#    ['RmJtpZrGGBFy', 'esuhvGzeuULT', 1000056],
#    ['hXoWmRUippud', 'celumZXdeOfH', 1000057],
#    ['vqBHejZRBGaS', 'NXWSIOETrYZP', 1000058],
#    ['ODHONfGRdRXl', 'IzbHLnXrSZMm', 1000059],
#    ['tEXpZKQpWqjj', 'AHpHDblkQFOR', 1000060],
#    ['JNLOyUrYDTXh', 'tbSXWAJUuXel', 1000061],
#    ['UTvGPozhGCrZ', 'UWiJnRDIgqOt', 1000062],
#    ['arjlVgBlGmKX', 'JwxzRlpfWWzI', 1000063],
#    ['AGKLkPovsgfK', 'wlnBYqIQECEs', 1000064],
#    ['OpPWpJfwEQMi', 'VOPoOdDNPSeD', 1000065],
#    ['OsxsShfSTxWd', 'ZDwKsBGisASk', 1000066],
#    ['JIIQcmETVKsB', 'qtKbBLybRJZb', 1000067],
#    ['mXqizUNQRkgo', 'ucnydUYRiGDI', 1000068],
#    ['pZRViSSpUDDM', 'CJwzdANMCKTm', 1000069],
#    ['zebfcFOpPFsV', 'flOQtljkcYXb', 1000070]],
#   [['uCXdUtMqvVIj', 'JRalplrRAjJL', 1000000],
#    ['clOEltJjMyGM', 'yHQRwKzhhEaB', 1000001],
#    ['SzyqpjHZHape', 'IJNMqqALaiNT', 1000002],
#    ['vQPDcMZUkZmD', 'WglGtBcdGYWN', 1000003],
#    ['mSJPtpjAoiHK', 'KNPsflZWuhsb', 1000004],
#    ['OxlXgFMAlZlG', 'PCcPOiKcdceE', 1000005],
#    ['QMmojnKDokzj', 'EFDcsPTEZJQI', 1000006],
#    ['XZRvgeilKJwe', 'ywGOeGjofuvu', 1000007],
#    ['eMwHENsLcDeY', 'IHydvdUXNRgv', 1000008],
#    ['iajlFiftrHdR', 'QMYgmUygmNpp', 1000009],
#    ['bCEXyxPrtpEn', 'DvhqnByiVbfS', 1000010],
#    ['jvDDUVlKwshq', 'ayqBgpZsItNS', 1000011],
#    ['SbTZfEATmNGs', 'rBfpQomWXTDP', 1000012],
#    ['zLkFhaOTYrwY', 'fFMqGpBYpvkq', 1000013],
#    ['HZMKjEbRyscK', 'rUByuYSuMlWI', 1000014],
#    ['AkqNlCvipvdg', 'SVqfJzyXvfqP', 1000015],
#    ['SskKPrjCxaHD', 'TNbDwZDpSLgj', 1000016],
#    ['aEDaCWsQahJG', 'FORTQDrricys', 1000017],
#    ['jZYgsypccxJm', 'LsrxLpmQykeQ', 1000018],
#    ['YTNMTchdHaPp', 'yEqeUPrnBQtu', 1000019],
#    ['RRQZWAwWrDXO', 'INYKBnHvgfec', 1000020],
#    ['sxjoVKNzgxMf', 'MWDvgCQgaWLw', 1000021],
#    ['eHJOCBDaOBJt', 'UaRJxDGBMDnG', 1000022],
#    ['zlabtjrOCZwB', 'fUgVtmItrpLA', 1000023],
#    ['dvXxiCuRRxsi', 'EbmjkOvYGAjI', 1000024],
#    ['vZfmpoxwQazS', 'dJCpENMwYRgh', 1000025],
#    ['wwdfYCqdkaoq', 'TPbiisjqIFdU', 1000026],
#    ['TjIjWITMrUOy', 'kgMnHzkADNsv', 1000027],
#    ['uQBjRGsowHgl', 'UsBVlNlxxIQq', 1000028],
#    ['dHDKxytRWwva', 'EroZfqorcrVr', 1000029],
#    ['uyGmNhhlmcNs', 'AJLkfhVWdjaF', 1000030],
#    ['WKBeAjOvTRzo', 'vJeJmJAGIACi', 1000031],
#    ['gFFHHOYVzIWr', 'yMJNYkWKmlJL', 1000032],
#    ['ADaSBXNxvMXX', 'vIJLBlKESxWm', 1000033],
#    ['ZaRENnVlvjGv', 'TROzWjwvoZBg', 1000034],
#    ['bHfTsagFwCmt', 'wGwoBtZxWpFm', 1000035],
#    ['cCflWUWcTLYm', 'DaiDshuxLpTd', 1000036],
#    ['SLTmpGvrfCds', 'KArZDwiLonAH', 1000037],
#    ['vpYKlGcdgmHG', 'sJFTALrzMlcJ', 1000038],
#    ['NngfkxUwclzr', 'pFHBUGszgjkb', 1000039],
#    ['OqSAldTQWBAG', 'uqqXwyKHNvef', 1000040],
#    ['JklufnpyvStP', 'ASwTMjrbmMiD', 1000041],
#    ['TNEoYGcGpsnX', 'vdeCYcoMLhvA', 1000042],
#    ['cAzEAXNEUckn', 'buHzTsnGOjof', 1000043],
#    ['kGxmngtlTHUk', 'BlRNuuKIXEaZ', 1000044],
#    ['rbtXTqssONrz', 'PJaMIlNwDqgb', 1000045],
#    ['WmaKEylrFPfh', 'UeVgrQvTCEaY', 1000046],
#    ['LAITvkfRUaQO', 'bYcuTZrBuBkO', 1000047],
#    ['vYRerhcOeHcU', 'BOeqpNrITfmT', 1000048],
#    ['LeXPYtFNLBlP', 'nkSBpTuWLYBK', 1000049],
#    ['udqGYYMcFjWY', 'MgPWSwYoRmNB', 1000050],
#    ['sMhDlesbXvYJ', 'bXNZgNEvgAlV', 1000051],
#    ['icKfKFvvbNXg', 'hIHmsfHmzBSc', 1000052],
#    ['gMlFHhzkxTHW', 'xXphtZsLuCMk', 1000053],
#    ['jYZJKZOsOgCi', 'rlNgpmwYZKiq', 1000054],
#    ['cwsYcnoyglfz', 'xufTpCYKDCHS', 1000055],
#    ['NAYCTUPBdULU', 'CGvQIoEVycIF', 1000056],
#    ['kNHZhAQBRZJW', 'lJsnRpOBsxON', 1000057],
#    ['OFEFVaauVoXl', 'BNSBpqeqRuwv', 1000058],
#    ['bYkaUjCfRWHT', 'PTeKiQcWYMci', 1000059],
#    ['LpqXoyYvrsFm', 'hKLhdWxPZayi', 1000060],
#    ['ndXOvwTZRQqS', 'OoFbaYcQppEE', 1000061],
#    ['GejuQNzrrfYE', 'EpFpVZzvgcuG', 1000062],
#    ['xMSiOHGfHxJO', 'JypbBKDhApXy', 1000063],
#    ['RQbDZSMcdGhb', 'WBwqYSownxJC', 1000064],
#    ['FsexCnfquGrH', 'eoaVyzfHSIFt', 1000065],
#    ['xmiZItmmcgPz', 'vPwnpxqtoKDJ', 1000066],
#    ['gFeSJPvqwJYY', 'DHzNVTuRBSsP', 1000067],
#    ['TVSmhdTqnowf', 'cfQRkolzhdgk', 1000068],
#    ['XCosmghRYYlB', 'accXtNQjntqa', 1000069],
#    ['jcRjziPKgBHQ', 'woQBBoZbxbFj', 1000070],
#    ['BiKgTbCtlJmR', 'RwQziIMEkfBJ', 1000071],
#    ['ncWqBJlsoUNn', 'lIwCrmidcbSH', 1000072],
#    ['NULfdHIsNAVH', 'UmcePHFAaYqm', 1000073],
#    ['xJSxrAidksXK', 'WGITMXNVisHI', 1000074],
#    ['JTGUbVYWvMWO', 'OxrJBiWgvwzG', 1000075]],
#   [['zlMbdBRpPreN', 'HFgiZpwojTvn', 1000000],
#    ['HrtWafzvXAgZ', 'FkPRixxfrXnA', 1000001],
#    ['ZgARVhmKJWsy', 'TrItfgyfuMTx', 1000002],
#    ['nMRcWwScwcff', 'psesJLJEQtPd', 1000003],
#    ['ZCIDFyNCYLqC', 'SrnkpWYqAQxB', 1000004],
#    ['jJXxtfARpxOO', 'kQVaVgtdRxXv', 1000005],
#    ['FQRxSFciYdaq', 'aTcgfnGOiwrx', 1000006],
#    ['CBiMHznEKCDD', 'lpwTbzihtEWY', 1000007],
#    ['kiGHQmyPxoRC', 'xSKdjXyMLOBO', 1000008],
#    ['HejigkrCHnDa', 'fODCXpSGRKKV', 1000009],
#    ['pAIOaxJJosxD', 'giFxZrzVxqXk', 1000010],
#    ['AyxAMQDDhSVR', 'KeGLAlmujAtr', 1000011],
#    ['eYZNACHCCSKE', 'vktgeYFwpVwr', 1000012],
#    ['OLzuCMBulQwK', 'ViQtiETDWBjs', 1000013],
#    ['RhPmJTUazGKi', 'uACWjanRKIri', 1000014],
#    ['CeoJbmhMUDac', 'eqgJMzvqXXlg', 1000015],
#    ['rYbQqWHAfKeG', 'PoAZXKUwfAYw', 1000016],
#    ['uifMUEZjGCQl', 'pEkBDVkomrzV', 1000017],
#    ['uAYuiqxgTHUX', 'woRmdPgOhHsB', 1000018],
#    ['warmJjCZIsfB', 'xrrxLnOgqDaH', 1000019],
#    ['UUHCPXXOnUgj', 'ISFsiWnqTSMQ', 1000020],
#    ['wBoBETEpkMzP', 'VUnDRJPPRFZf', 1000021],
#    ['lvSXHHpvQjFz', 'TrsvjolhpJFi', 1000022],
#    ['eqbgGMYHuHLw', 'CxaIkifXrtEE', 1000023],
#    ['liRZczwnBmng', 'ImFDLPdLknBH', 1000024],
#    ['oQqTvwtFdTXu', 'eckMSpzkEzma', 1000025],
#    ['YbNDBlnmjAzw', 'vwkXKJDRggHg', 1000026],
#    ['NEKxDFiiwtct', 'zmXNTkoTJxfm', 1000027],
#    ['QLskGrmBGKSy', 'OkEfuucjflmF', 1000028],
#    ['VXmDtvFYGjGo', 'LPForjrrenfF', 1000029],
#    ['OQlkABKnMEyK', 'eADqTLJVKqjO', 1000030],
#    ['CkUMNubtvRpn', 'UCuBDLMkgkXd', 1000031],
#    ['xCfALmnZPQFO', 'nzLcBGZfeTZu', 1000032],
#    ['wGPJQSFwgSJd', 'JjBjWAVwDaNt', 1000033],
#    ['jsUTKbWnezix', 'KMEwzmsmJClp', 1000034],
#    ['DgteRkdorhQm', 'kisPmEIoRxuZ', 1000035],
#    ['DMvsJsPcKYuA', 'YYYyliWFIsjx', 1000036],
#    ['XnRVhBJYcvUw', 'ADZmDLrEBneV', 1000037],
#    ['HHDBaXuhaiqn', 'yTwEesFRePWd', 1000038],
#    ['doKpCkBeODzp', 'zkUzrUXZABpw', 1000039],
#    ['KSBOBAIkRtGZ', 'cetXMDLXvsVK', 1000040],
#    ['biSkxvSiUzcp', 'VyOaouHNospB', 1000041],
#    ['WMxiqPDkcwgc', 'JZCaJCdxKJnV', 1000042],
#    ['QEKagvvmlDLT', 'WubwpTnGSHwh', 1000043],
#    ['YfGVHGKpXlRB', 'rKFYVGyxBPKK', 1000044],
#    ['rBEVQNDtUXSG', 'oaGVochiMDvF', 1000045],
#    ['XXMtQQiooYhC', 'EFxQjkkPLWTa', 1000046],
#    ['eMPHpSPhgMSh', 'AemaXHezTCnS', 1000047],
#    ['xeoaAFcCNtWq', 'iAaORJfmILPt', 1000048],
#    ['nZdObTbJKShn', 'FPSasZJgTslc', 1000049],
#    ['FDxOjkoFthxR', 'stDzlyndCqQB', 1000050],
#    ['CyWceRrvWgQm', 'iMbDmaVyahkT', 1000051],
#    ['eDOiqKrLliBv', 'dCJBQaCfeHkK', 1000052],
#    ['KTrULAvhaqVg', 'CvGnLgQPeGBe', 1000053],
#    ['zLTjsOrzvukv', 'PBqqAdVxOGqH', 1000054],
#    ['uNHiPiQAfzmT', 'LcntcuRmEZDs', 1000055],
#    ['OhJOxBLqRxNp', 'cIZWeQysThsu', 1000056],
#    ['raNblyTyPlAa', 'OHEYWNUMTbgi', 1000057],
#    ['fVewCCRPabSe', 'xTWifMFitPzk', 1000058],
#    ['lUdyKOkQrxkJ', 'OBzDTkJqdfOk', 1000059],
#    ['MVzHksFnoedK', 'JhUyZgFnEKVS', 1000060],
#    ['TJkEgnKqfRLn', 'aTRqIknMTtMQ', 1000061],
#    ['PZHxjPwORmga', 'MocRbmonYqTP', 1000062],
#    ['yQDCsquEDylo', 'uyMqgBCaSKXP', 1000063],
#    ['TASiFSPbIyXu', 'AiAHeIdtzLUf', 1000064],
#    ['PoFgNfbrreoW', 'hZDdyoxpAZZw', 1000065],
#    ['xNvsSCWErGrI', 'lagJQCJAwdKK', 1000066],
#    ['mYxcVecmXYzm', 'SEpUDCUyKIhj', 1000067],
#    ['phLmmAczOkTf', 'pgfJooQKYvZS', 1000068],
#    ['ziZiLdeprrVg', 'svxKxGhXSNyC', 1000069],
#    ['adPZmpKazVMT', 'rSKsYniZnkCR', 1000070],
#    ['lhogXBDJMPfT', 'npBzlnDgUeOp', 1000071],
#    ['mgdSgkrmIebP', 'bgHjPNRicjzK', 1000072],
#    ['ayDpnJYFMiav', 'hQEnFJPAsDtO', 1000073],
#    ['fucHCbvjqvsf', 'LpkuUoaDgdwh', 1000074],
#    ['GJZSlGcxDhgb', 'ULGCpvjbcdaM', 1000075],
#    ['eaoPortiICjO', 'AGRaZBJKgthq', 1000076],
#    ['KvqWHNmOCwbc', 'ZtFTtjKyboQI', 1000077],
#    ['QcaWBIOPZXLy', 'POBHXdswmTIT', 1000078],
#    ['WlXPCMbvnZYD', 'ictOHkPxAlWc', 1000079],
#    ['VjBovpoSbnIb', 'DioTelILeMdH', 1000080]],
#   [['zwcIaaMZtVJn', 'uarJggxmGQbV', 1000000],
#    ['JRVMNaguZtdo', 'TFPFehaTKLDm', 1000001],
#    ['mzswxzZtPoWV', 'ElnqTzSHOJdC', 1000002],
#    ['ULfHDoqrUxhx', 'WpKbAssIxvNt', 1000003],
#    ['CfcZmVfwpRvr', 'iHwBnkuxSQKN', 1000004],
#    ['GAFfivNuoPYJ', 'sVquvQsHnEUx', 1000005],
#    ['bXLwrWrwaTKZ', 'tVywIlIntjMq', 1000006],
#    ['OCynHdkdmJGd', 'CGwZJLZbtjVm', 1000007],
#    ['ywgWliyoHhfo', 'NBlBnCplGost', 1000008],
#    ['hSOlulCCoGvz', 'RBIlUNczCKVE', 1000009],
#    ['mDzwQQJHyBUy', 'bhoWsRSLpqLm', 1000010],
#    ['VjTTfeTTxPSL', 'JxhcmrktxKnT', 1000011],
#    ['ozRaEQNSmVgR', 'lvRNmqCTEKnM', 1000012],
#    ['xhVnuKQAiGhF', 'CPvnKUnukmxc', 1000013],
#    ['tIKpBBNkCJNV', 'TcLzcxjxkyka', 1000014],
#    ['YuQhSwduztoo', 'JBJFjiUpYdtP', 1000015],
#    ['WfMKYbUeHAgA', 'adtFjimMRUjX', 1000016],
#    ['fjBUDxDShQpK', 'dxyndLKeJpcA', 1000017],
#    ['LSywnRpdWfUo', 'eMdsAiCcqhIN', 1000018],
#    ['EMAxpKTahwmC', 'PpAcvRHKYDlA', 1000019],
#    ['cEPLpVlljFBY', 'zxOBruvkUjlN', 1000020],
#    ['PvjHRdjfhlkx', 'tcomaWHkyWUr', 1000021],
#    ['HJdZcjgHvSRL', 'pvZWbdOqCeDI', 1000022],
#    ['uLSkofIePBbx', 'YsrimvhwSHnh', 1000023],
#    ['zMSANMfzVDpQ', 'ojavTabdanCe', 1000024],
#    ['WLOUDOMGsWXc', 'BvVhbElHovMB', 1000025],
#    ['gawGiOZjxBCm', 'okvtAWFwtMze', 1000026],
#    ['tZoKANBhGyAD', 'FekMeMNUaCEN', 1000027],
#    ['SZarbZfnQUak', 'DpCQTewALBkq', 1000028],
#    ['iGnBIfTDlPmU', 'tWcSjakQNOOs', 1000029],
#    ['udvgZxdpUjvr', 'PMuptZHQixcr', 1000030],
#    ['ovYpJupSRJYV', 'CCHJcuDzUkjA', 1000031],
#    ['gRLFUYfFAzAb', 'wUJjPdyNgMGB', 1000032],
#    ['ooSRTVhSAoOg', 'pskxDtYOvwlC', 1000033],
#    ['NqhNeAhFScYj', 'tMZjDFSnNKnA', 1000034],
#    ['vHirVhzseRnu', 'rEQsxHUPNwkJ', 1000035],
#    ['vALRnslYjaCD', 'HmccKxVpsoXW', 1000036],
#    ['WgUSnfFEyQBb', 'LdhWbdELQjku', 1000037],
#    ['vxwGuvesofrp', 'fVVKdbSVGcQF', 1000038],
#    ['xpzbwttTfoXK', 'XbfbNvWhGFPY', 1000039],
#    ['xuhFnESGIKJT', 'brNanvZPKJtJ', 1000040],
#    ['WqlzdSJOQlJm', 'KuViyjVJTDxp', 1000041],
#    ['acMyJXsVMYuK', 'UPoIncaGufvu', 1000042],
#    ['ySpjDLuklFmJ', 'rwAZxYIhruLl', 1000043],
#    ['IGcJGsKnOhSx', 'gQUBSuZMWlLW', 1000044],
#    ['eKrZCKbNdyeX', 'fQQPLvpQzTJe', 1000045],
#    ['HupKDLyNPeJd', 'xbhONwbhNeXq', 1000046],
#    ['glonvTLcKldT', 'TAdewSdvtlua', 1000047],
#    ['VeFyrksYXfYG', 'KHDZwErZryWR', 1000048],
#    ['bNpaAwLZNSYf', 'zUmHNiOGZrit', 1000049],
#    ['oclOEIBBIRzi', 'prGBGqLRHEiU', 1000050],
#    ['sRUOwURxurWV', 'LtyvldmvgWYT', 1000051],
#    ['BlWniSKBfvfN', 'QqCktWyfZSvQ', 1000052],
#    ['MlCpGMEytzHH', 'BkGGjUOqGBWX', 1000053],
#    ['wgAipOfXOuAa', 'JWSOvdKaNTwC', 1000054],
#    ['EJXFWaJhoTPE', 'jtNulQBarCjA', 1000055],
#    ['yfpGXgVeGJsS', 'SSLPjcHbxVMk', 1000056],
#    ['rVOfPvqtWXpT', 'EZoLJweXKoBC', 1000057],
#    ['odpvujLclWWv', 'euYUSrXxITHA', 1000058],
#    ['FWYgVxABaAzy', 'AHGXgIcWaUKS', 1000059],
#    ['zGPDHswwGpop', 'SLbAwUzDaUUF', 1000060],
#    ['UjVuGAhgoCPe', 'bBNqVvEbtUbL', 1000061],
#    ['mgvXDXmzdThu', 'RprARMkvHhud', 1000062],
#    ['QWwfrnKkwtly', 'KOBcmAvsDVJm', 1000063],
#    ['SaqELGMooHnP', 'ANsvXYQqXTMh', 1000064],
#    ['LImzDjOfJqPo', 'MxDqiwUjxuUT', 1000065],
#    ['KgHQVOdwNTZm', 'vTCLzONSrPoK', 1000066],
#    ['HBiQrkLYsjKP', 'ZSElkkxvWHdp', 1000067],
#    ['gLGODVugDJdE', 'dGFzaiCVyBvw', 1000068],
#    ['LMlEpkTqKziJ', 'vKjVRASChYkI', 1000069],
#    ['gvXZLzCxnBmx', 'bSWJLsiiNmce', 1000070],
#    ['CsFjZWjAecqq', 'fQYaaHqxIoKF', 1000071],
#    ['kfspZlkDlAbX', 'nlCMuSokMAPu', 1000072],
#    ['HNdUuptWVvWr', 'nwEmnKItbtgT', 1000073],
#    ['yZMmudnqaLMG', 'jsYUttzmEftZ', 1000074],
#    ['WYXrENcUIMYW', 'KagNCulfUnNx', 1000075],
#    ['IAodPycOShtV', 'LPWlooQiJiYs', 1000076],
#    ['XAXHTxeTnxSJ', 'szOkjiVIYdlY', 1000077],
#    ['qwwBSxViTiMK', 'MYnDkDjriIOM', 1000078],
#    ['JYFQYdKfVTly', 'wBOykXQyXkMk', 1000079],
#    ['KDkDDIsfYkHu', 'mABwEmPInVNT', 1000080],
#    ['UEtvosHfvDSf', 'EGcILUiyFJvn', 1000081],
#    ['flEOTVdImjch', 'SiqUBynjcZYT', 1000082],
#    ['HRkLAiyijnBV', 'nrzoiEWHviKP', 1000083],
#    ['NNTuXAwrvdEN', 'vTFasaYuubuh', 1000084],
#    ['OLpDuvftfxsf', 'pJJjTsefYuGz', 1000085]],
#   [['gyHviHpnPqHo', 'oyLzFscXNZKS', 1000000],
#    ['eSgxRSaxrwyy', 'WotjIPluReaO', 1000001],
#    ['IBsBHXKQORiR', 'IepNiYBBotoh', 1000002],
#    ['GywlXuOyABZZ', 'eMqYEiDJpHvm', 1000003],
#    ['oRsVBqesznpq', 'jNiOCithRBnI', 1000004],
#    ['bOWfEuIwwakS', 'bXWBaxhuAwAP', 1000005],
#    ['udVbsmwBtSay', 'rebpdxlDaSQL', 1000006],
#    ['TXvcnndjIQTs', 'ttJzYLwUfGfV', 1000007],
#    ['ycCwldOMCUdW', 'ARbqCGvrDaYB', 1000008],
#    ['WPRqHfBCQKnq', 'izyCgivpRBhJ', 1000009],
#    ['EzIzbYVZAohQ', 'FOQwOsTYQLCe', 1000010],
#    ['cvURCUEqFWnJ', 'tPxyuxSHnwbg', 1000011],
#    ['jLYjkxjcuRKk', 'eNLNWXZedANh', 1000012],
#    ['KQpnWyrXyrLL', 'QRhrCjHjAfrw', 1000013],
#    ['eRLCgulEoKpa', 'QpbEhjzqXbIC', 1000014],
#    ['OdiozdhpzsjM', 'ohAYxwtToubo', 1000015],
#    ['OveJWanFrLcU', 'RERrAEwDlTOw', 1000016],
#    ['cagaEqcCXBaV', 'JZYEcUoFVpaq', 1000017],
#    ['bZwhgEhbaxFY', 'uuaESNuLBSvO', 1000018],
#    ['IqnDmrtbwUfE', 'SKYsUEwPdANR', 1000019],
#    ['LCAYQRWBVXVD', 'hFPJWAcMxtPg', 1000020],
#    ['krkUGEiluvNa', 'XewOGiCMYbRE', 1000021],
#    ['CeHiNrYmuBVf', 'jSDTJKIlkcDQ', 1000022],
#    ['CxuyLBMiIQtg', 'JwPdswTpUrUL', 1000023],
#    ['FlLnjNIhRZLb', 'RVeqLGeOqnlC', 1000024],
#    ['VdIaLXCLkDlA', 'jGvjSiSEkUxm', 1000025],
#    ['lbIokLxpLnFO', 'eGBxzvpxwyXe', 1000026],
#    ['WlNVYmnKovQn', 'QbzwybbGjaqT', 1000027],
#    ['IfvttqmSZlsI', 'EtwlJMkXSGkJ', 1000028],
#    ['GkryMTcHnvJC', 'hFTAfzfcMcty', 1000029],
#    ['WBNJLKKbJUGE', 'okItUdOHogjU', 1000030],
#    ['fwvDDskoTXgc', 'TyFizzjMhuvq', 1000031],
#    ['unVnSCuXZpXm', 'KjVkOTCuOuIn', 1000032],
#    ['RSVkvIFGElTl', 'fLEgJkqELHEJ', 1000033],
#    ['HTpGobDGjknU', 'vxQiPuPDkbDg', 1000034],
#    ['RmvZglQbObxi', 'kXwCMSoUnvqi', 1000035],
#    ['nxzhHxcpVPJW', 'uErtPUYLiYjA', 1000036],
#    ['cKBGLfcAFvAL', 'IGNRdeyerLVU', 1000037],
#    ['npNQnpdqfTgq', 'AFWeAVZRoSHo', 1000038],
#    ['BGdCywfEhoxj', 'aboLUhbkSrEr', 1000039],
#    ['uuvHtoglQPbW', 'zScoqHgQvNKR', 1000040],
#    ['JHoCEvYgOWPn', 'VHCUwmgoVqXh', 1000041],
#    ['VyXQLBFmZRvX', 'vqhvDRcMTYKE', 1000042],
#    ['zckVZFuFbvPp', 'OvJflXsNWNJP', 1000043],
#    ['aCcqdtNpRfTK', 'qxCQETYZKNOo', 1000044],
#    ['DKVsGNWnoNCp', 'NjwPSuSYjpOz', 1000045],
#    ['EzchpApQVyLf', 'ofYuTeVZFJST', 1000046],
#    ['JXNwhFcAMgPx', 'CtpCMLKGgDtd', 1000047],
#    ['HOeruFGvyBEU', 'FGIgjhuagpkG', 1000048],
#    ['obVkArrUJQhO', 'fryHxOftGvpO', 1000049],
#    ['VJyQLFJXnclx', 'ODeJReiqHekF', 1000050],
#    ['FFofoCrqMKEW', 'HPoDFTXyWzZs', 1000051],
#    ['hxZllKPXvAPj', 'sDQnfshynSgj', 1000052],
#    ['KPJzezXDiMpO', 'SqJwDYqbLUxw', 1000053],
#    ['RZZLCvkxirva', 'thfVXbhmOjWd', 1000054],
#    ['nxXpGPnNSyHT', 'SHMgeMlnoItM', 1000055],
#    ['GVnQVpjWQNLi', 'qeeDQnkFefPU', 1000056],
#    ['WMhLCgCsKCaY', 'SRiqLEUDaMIg', 1000057],
#    ['AqsxtcocHAqP', 'pnKjJcwapDKd', 1000058],
#    ['vLauEtSZXMgo', 'SOLfRrQqWKLK', 1000059],
#    ['YVOjzecwVyFQ', 'AWkBDeOvsWza', 1000060],
#    ['EyMLqVPCoURf', 'izxeCvGmQASj', 1000061],
#    ['WQpdqAzvWNrK', 'nieVlzqsxJRD', 1000062],
#    ['PPeNdfKivzrz', 'OyteYQWrxTfw', 1000063],
#    ['zicDETGdHyOw', 'boGKMdfxHWUf', 1000064],
#    ['dqRqHIgXrqLb', 'qEkibULukrIb', 1000065],
#    ['tdVbjyNtnvAP', 'UdwInPWdPBdq', 1000066],
#    ['MOwISiqOigxI', 'TfUzCaYXtWxZ', 1000067],
#    ['IrrrMqgGUIaA', 'TsNmSbImOJJa', 1000068],
#    ['uGkeFaAqeqBW', 'xpPdCpxYEkUf', 1000069],
#    ['KAjIieXdgihj', 'WdrEtbWVaMyi', 1000070],
#    ['XxWUpdMIBLcE', 'LzFAzOEhwPtT', 1000071],
#    ['RZbaqaKvjkSM', 'QCnSXLJGsidk', 1000072],
#    ['HAQibZDBFsNO', 'HkSPIlaaRolN', 1000073],
#    ['dVNMSXidFZXk', 'rRpQmdfqCliX', 1000074],
#    ['uBXSewzjDDtb', 'TsIyatzaetrZ', 1000075],
#    ['DzgfckOmljhJ', 'TOSVlakmfAMB', 1000076],
#    ['FvOxhlMdoiSM', 'rvLXzMyEOOcC', 1000077],
#    ['GLOEWGIWPndt', 'zwAJMbVDUubi', 1000078],
#    ['RNdQCobGXnVu', 'kZtgyqvZrUnm', 1000079],
#    ['HTHjWYFVeOgC', 'IEatjRWfjTnL', 1000080],
#    ['kceXxvBVvQZT', 'BFoJtwMSGSpD', 1000081],
#    ['SIHTghQYkyOA', 'zdGLUhZblUjT', 1000082],
#    ['rtzcCPCBcLhy', 'kUUGzcDmUjqQ', 1000083],
#    ['cJYKkWEVtDUj', 'OgbZEzkeqYfs', 1000084],
#    ['gTvkiAjVZnps', 'QwdvPJrZDrfB', 1000085],
#    ['vbYMsuLFAviw', 'LGMIALTLVvCC', 1000086],
#    ['FvhLpfkBcCby', 'tmUakcCOFiWd', 1000087],
#    ['oNbqPqZLPUJo', 'zXWaPMXjqXKc', 1000088],
#    ['pDSiJuRXURKr', 'AaCMYshnEVpn', 1000089],
#    ['USYxEDRLFtff', 'oxIpUhNXZEIO', 1000090]],
#   [['CTRXazSuwUDy', 'PwhSQtKdigkd', 1000000],
#    ['RxRNjdQMffcG', 'gzPDfzoAfcyD', 1000001],
#    ['SSCRtMOnYUwa', 'mpcRqsJyqaCz', 1000002],
#    ['DKDEZRarTHyr', 'YAVzZmytsVdL', 1000003],
#    ['wYqBpFpqhsKU', 'LZcLxCFvCpio', 1000004],
#    ['yCPaqsLdRehZ', 'ZnGPoupjhhft', 1000005],
#    ['AzLyKevIVskm', 'QzvdIcJMofGP', 1000006],
#    ['avGVMaJXFKoR', 'ZrykecSSAulo', 1000007],
#    ['usuduKohhNTi', 'wwHqkqjBIamD', 1000008],
#    ['FUkwzFtSCnCl', 'YwFcXdiEEltH', 1000009],
#    ['JILZGAaxYUXt', 'BKavAKrPEAdQ', 1000010],
#    ['iEMqIUVrULmH', 'BMFaKZKUygiH', 1000011],
#    ['CbUIgVqiVHjY', 'ZQgfDiCxkkiX', 1000012],
#    ['PyCyZcUZdQYu', 'sabFFkjdMNNa', 1000013],
#    ['OymJfaOxDVeD', 'STfpFzIcQVrB', 1000014],
#    ['gpXjvYKPgFYb', 'NtjOUlookpaT', 1000015],
#    ['AqOLMUgNFjaq', 'dJUkSpzhtYPN', 1000016],
#    ['YPjXpxzqDyzi', 'AlRpygwrmzgg', 1000017],
#    ['miMamkYdEkIh', 'jEKwBIlOcNij', 1000018],
#    ['lHOMGIUrDXPl', 'beNJKKAgBjBp', 1000019],
#    ['JfRCnxXDQRRg', 'cIWxYelXOeLx', 1000020],
#    ['WFzWnWXCQXFq', 'qgXLTHIpjJes', 1000021],
#    ['JUagMXrgzIzZ', 'QmmWAIBoZfct', 1000022],
#    ['vZvKNdfjdjEA', 'whyZyEKUjTWR', 1000023],
#    ['bXzhGPYqOYqq', 'FnZoYNYOKIGj', 1000024],
#    ['QQgVoNMFXdgL', 'FUpSNAFuQSjG', 1000025],
#    ['PRQjndFZlBAo', 'pZmXTdXNywjw', 1000026],
#    ['lPFYtEJIQrro', 'HyVGjOjPTUFy', 1000027],
#    ['iirFukTPqdzH', 'myAWVJGCebuF', 1000028],
#    ['LfZGmxlfVTMk', 'aJFaoDhOSdRx', 1000029],
#    ['XoLmcTiuEeGz', 'ifysQSxNMlOe', 1000030],
#    ['TcqlLLEohQhM', 'zuTRuyxaFHZh', 1000031],
#    ['JMfXhgDTNWzj', 'sgnCuKZvDKvZ', 1000032],
#    ['cECPiJwDUueX', 'zfwacoRxxzxI', 1000033],
#    ['fujyeQKpKMCR', 'RAxSMcErqNuO', 1000034],
#    ['GYYUtKbhGSOo', 'jlHgPlthmzal', 1000035],
#    ['TlQcdIMHqQff', 'eoKrHhtFFOoS', 1000036],
#    ['zzokUnSnOrem', 'yoTckNmWAHfB', 1000037],
#    ['bsONNYeQigHk', 'lDRRqWYnRMmX', 1000038],
#    ['glnkUvaIqBbL', 'rDIeIuBPJNKZ', 1000039],
#    ['TiuuFCTfuWds', 'YaLTtxjybFpG', 1000040],
#    ['NZvMmaViDHcA', 'yUvQEiYjltuJ', 1000041],
#    ['FLaCQHXHdfxY', 'OuVAErktQVEU', 1000042],
#    ['winxuKEvFSwH', 'nOdhKqEeHYzT', 1000043],
#    ['bVSKQgYITTNd', 'rvmNAhLymWLs', 1000044],
#    ['aoSbxMByPPPC', 'CLmYpYtRGgdW', 1000045],
#    ['QXLQkEKBFJTO', 'dKsiupNjpPGt', 1000046],
#    ['nJOLtziSjAUf', 'WEIbkssctmIL', 1000047],
#    ['njSihSSTHKPG', 'HZdhGbcFCaph', 1000048],
#    ['nBkUdVineCvi', 'BEABXprpIHXw', 1000049],
#    ['RbgKQTQsJgJi', 'SBiwVvLqHNfX', 1000050],
#    ['aOMxUfQvhYvd', 'SlXukiIAFgAI', 1000051],
#    ['GHyWJewHjCiQ', 'mxayuJzCSLZc', 1000052],
#    ['cqeZDJvzWUFf', 'jWCPJwpvHEXz', 1000053],
#    ['YBIneDwGTjad', 'BAAYUXFltmMJ', 1000054],
#    ['dsRwnNnDdmFV', 'fLcFrORxLTQA', 1000055],
#    ['udIQXCGPrEec', 'poanngHOhYxR', 1000056],
#    ['gWtEGSJSjvBN', 'XMVwdeRCXVcy', 1000057],
#    ['aoVOTnRaHIKg', 'MSSWQiBAAtDL', 1000058],
#    ['uGXKqbxbPAZT', 'ORQlQqhuamXy', 1000059],
#    ['gqaaFUiHPbkn', 'DozSWpkAqwfr', 1000060],
#    ['wGVGjKPNSiSK', 'azVomgxRrfEY', 1000061],
#    ['gPIszGNETLYs', 'sphtcYWOTAiC', 1000062],
#    ['RhlkSWjGpdgZ', 'xxXCtTcTNUaf', 1000063],
#    ['fTYPjRYBjSri', 'cmUoenERvrge', 1000064],
#    ['aoTifHjqIdPg', 'nUWLORGSFUuy', 1000065],
#    ['EEDxgsrKJIIN', 'qrdhSIMeyWOp', 1000066],
#    ['bykpmCsnSXQC', 'dSGxFCyQlYAX', 1000067],
#    ['rUceOkpqPZGI', 'TQqkfizCpMzN', 1000068],
#    ['LHEQcdJuwdfm', 'xUGjPrgscbKl', 1000069],
#    ['bsdlQmMpbRNM', 'KWwKSuMucNWp', 1000070],
#    ['HBUXoOYcZKkd', 'MXwXuWrjEoqR', 1000071],
#    ['LRLjulfJyvHk', 'fGYLyEOVgvZM', 1000072],
#    ['LCwrzkBucWhF', 'ajujmMsrGPIf', 1000073],
#    ['meeVBdIliEDE', 'htjeGPIAttuO', 1000074],
#    ['WGiEjpicLAtT', 'qxzhktyaIzbZ', 1000075],
#    ['HoICEKPHltWI', 'cTWHUWFMPJrX', 1000076],
#    ['zaFtVpCmdpyR', 'wNtYfeeROaYf', 1000077],
#    ['cxzivSQoiGOe', 'BPFvXVfVnDEW', 1000078],
#    ['udaluEvGiENX', 'uGmZgfHWPMAY', 1000079],
#    ['PVoXYDvzeEuk', 'eeRDrLEIXuSP', 1000080],
#    ['MDZfqNErqPEl', 'aigpolzOyxEa', 1000081],
#    ['tkLgpsuLcffo', 'tBDNLCJWBVWo', 1000082],
#    ['CszesToWueCU', 'VPQXOTabKmpE', 1000083],
#    ['ofDjJMnDxKkX', 'rEgqFVKkhAKf', 1000084],
#    ['GCdEZXZLDzqA', 'xhVeFbXhrXuD', 1000085],
#    ['YNSiiIflYiSt', 'hoJVPlQpVfry', 1000086],
#    ['OfewzGwMuiFn', 'JVrQfaHZgrvI', 1000087],
#    ['ugwyiBHVELDx', 'HSFFbYOoNWJg', 1000088],
#    ['dsegKdZKDczm', 'VovqdsJwCeAw', 1000089],
#    ['FhGFFKkvPYIR', 'VNeTJHRluLlz', 1000090],
#    ['JGRzLwWfVFqg', 'MCLFyTfKhwLL', 1000091],
#    ['rRMqCPbKLydV', 'OtmNefyuzeod', 1000092],
#    ['FYfvOKpmMTyF', 'mUyyWzlJqJhO', 1000093],
#    ['MOCbhSWqbJDf', 'KjOfUvwJGHwn', 1000094],
#    ['NqrwbNagcoWo', 'aHMVawQobpXN', 1000095]],
#   [['bHJhvWLUhwlb', 'uXVOnuXItpqk', 1000000],
#    ['qAMZbktaPBxO', 'XSEQsSMqUfwp', 1000001],
#    ['NKTbRJKMDfsG', 'prreyXbosgrp', 1000002],
#    ['tHKCfFcwWkon', 'PsglUBLuBpOB', 1000003],
#    ['jIDZpHXdjJIx', 'NHzGAKzjXdTa', 1000004],
#    ['FYHHbWvMwaTg', 'CaMQCfVEXkoT', 1000005],
#    ['YSzvAphDFLHi', 'FEzVzogPmCGK', 1000006],
#    ['iVLDCvowIAfv', 'hVtNwQtghZVk', 1000007],
#    ['EOjCdpvWvjSo', 'MlJPgVdfRqoS', 1000008],
#    ['yiJhMFfiXrwR', 'enehvYxqJlZh', 1000009],
#    ['AHfYnqZQZduH', 'NPllUlHXGwAC', 1000010],
#    ['IrBpuxqOJJbj', 'psTbgtdJTLkd', 1000011],
#    ['kThgZgYzujVm', 'QzdjsjHQdict', 1000012],
#    ['EkQotYHBHFMw', 'diGfJGflWitB', 1000013],
#    ['YQLqlaqXxrci', 'EOtEunUnvqUd', 1000014],
#    ['hiapQfOyyOcv', 'SUDjAdwbxyEX', 1000015],
#    ['VromdefiLZaZ', 'ABZvMVFqPmEJ', 1000016],
#    ['nLHQIJLtwjcG', 'SDiJdkXRFzfQ', 1000017],
#    ['ulLIDCFBAjby', 'FFmhQhDNrrBd', 1000018],
#    ['SgJdbtPMftDf', 'OMZnMeIRipGC', 1000019],
#    ['hJiknXvXsFQC', 'UlINatJgbFeV', 1000020],
#    ['MYBzcjKJUGlj', 'jCWByWliOaYK', 1000021],
#    ['XljocQeTCnMn', 'kIYXwnJmEzSQ', 1000022],
#    ['XgyoCkAgNLiV', 'vuVndOKTmiDI', 1000023],
#    ['gveKPyzkGWTE', 'LYQcmMIOBSiA', 1000024],
#    ['RrERmgmVHrza', 'pvoyLvzGDQhZ', 1000025],
#    ['fWhQyUKfRCLJ', 'LtWZVpbXTXTk', 1000026],
#    ['oxHFLkwbkvlk', 'KRBWCDGOIaTr', 1000027],
#    ['fclmbqHHdmfr', 'KXrzemjUTjYb', 1000028],
#    ['RMvOzYyOjYto', 'spOzlDEmGiuO', 1000029],
#    ['aoeqnBpNivfd', 'AjyOiCfxenBX', 1000030],
#    ['DIsstmAxdhMz', 'TXPxHJPDMFfP', 1000031],
#    ['gfqfQCvIELHQ', 'OaTwhlRWsZyo', 1000032],
#    ['IpnGEmzlvxYY', 'xUUgXZSaWPWa', 1000033],
#    ['ZEtbNYTGwkyX', 'bPDZHHOHAkdB', 1000034],
#    ['NxlVEIEMjNpj', 'tjlfTQUwJyxP', 1000035],
#    ['RclxCAPUpJuh', 'UQpUVLzRGeMT', 1000036],
#    ['sbLjuVKZBzIp', 'lELsSAWBWqSE', 1000037],
#    ['bmZHFkjSQxof', 'pviKYXDqgfni', 1000038],
#    ['ZMAeveraaKVu', 'qRrTzaZeQfjH', 1000039],
#    ['fcXqBOahCQqx', 'HoFCbncLqpJf', 1000040],
#    ['kmjWFhBoSVaj', 'sYnbRgVRuoXQ', 1000041],
#    ['zdpEniGxsAgd', 'sXlXCpvKwRoJ', 1000042],
#    ['diRsqtSjHVNp', 'ZdvCAcemXQpo', 1000043],
#    ['SFXkazdtZyDs', 'IAGviLtHmJuf', 1000044],
#    ['KTuVZhnDVuYB', 'fHcNcolzcXWG', 1000045],
#    ['zLIgKIYuPrpU', 'yalaKZjbFmbE', 1000046],
#    ['INkfsYqMNqUW', 'lsjbGzTPTmFH', 1000047],
#    ['FRDXbIhJKTIb', 'NNVaLzUwQZfm', 1000048],
#    ['QHEKjGEOmndU', 'WYsVbXNEGmNc', 1000049],
#    ['vFxHnORqLlSa', 'riNnFihneDEf', 1000050],
#    ['GnJJOBOMJEQP', 'ABPZblfgFhCZ', 1000051],
#    ['MqTytuKFnutl', 'QBMoSwijzDMU', 1000052],
#    ['BJOFXTVSDxvx', 'pDfEbZvzkZnX', 1000053],
#    ['VoshcVtmNzMw', 'BppssSUCcuGL', 1000054],
#    ['ikkUvumZGdVr', 'CgpAwNoWTIsN', 1000055],
#    ['MuwcVESMqKyf', 'FViHYpGISCUA', 1000056],
#    ['ayMUWAIDJIyA', 'gdEEIzLMsKTw', 1000057],
#    ['aAKVzIAQFMZG', 'vIHnWrNzNLTk', 1000058],
#    ['EcMgrkWqGXsQ', 'XksLQLClyoDh', 1000059],
#    ['KNewWnVFTqNn', 'rClNsHtUTBwx', 1000060],
#    ['vnBptQvHBPYx', 'aWECsWBsqSWX', 1000061],
#    ['LZahpaqzoWoZ', 'JyzEdiIZcIYH', 1000062],
#    ['FTTbMncVHUnO', 'awGEuLKUGqSC', 1000063],
#    ['VVGHyjNnrtdc', 'hIEJcJkefOOr', 1000064],
#    ['pMPXWDDRNHvd', 'TeEpcWBZYemq', 1000065],
#    ['cufaeSAnUMHW', 'DhKuDHHhwgJS', 1000066],
#    ['CYPhokSCJhTt', 'LWAsvLzboEMl', 1000067],
#    ['QwpITBokxULR', 'GjpBITxWlkhU', 1000068],
#    ['XEKLpaTxLnPs', 'faLWWNlKRMwI', 1000069],
#    ['iQxWymvgXZBp', 'eJLiEybZsVSx', 1000070],
#    ['VsqiJVQfowqA', 'mtezegeIKYCd', 1000071],
#    ['LgAYRNdmPoqJ', 'VdyUNvCAZQJS', 1000072],
#    ['kYYVVaNrsePd', 'uZydRVswZynP', 1000073],
#    ['knmTLkvfsfTl', 'lorPdwexTmmC', 1000074],
#    ['bJjcqDabShaq', 'JYJJXIvuWhVp', 1000075],
#    ['zcQbZjTSJFjP', 'vpRWmNnXIpaB', 1000076],
#    ['lkKkVBExjlHq', 'cRaLQVewMpQQ', 1000077],
#    ['JGRlNzJogqLV', 'VhZtFjDiiybR', 1000078],
#    ['EfuJTnCAVFji', 'OxmLHVNfJycC', 1000079],
#    ['LNOcuGefiWeH', 'ieQanOiHfgly', 1000080],
#    ['QUFzzlbwJmEu', 'sQnsAzAPkmtN', 1000081],
#    ['cQXEgvaVXjoV', 'QJTQWmrpdams', 1000082],
#    ['cljMsRySsJsh', 'QPcpVOwquPYL', 1000083],
#    ['IHvQWObOMaLB', 'WgxPkoVFSCBX', 1000084],
#    ['DzNbxBqDDPeH', 'HspvkERnhuWn', 1000085],
#    ['jWXZSbVWTtrd', 'zBuYYufqCaRC', 1000086],
#    ['BacPWBjRvZyB', 'lIlfPqwBCnEu', 1000087],
#    ['vtPTjxQMXzpn', 'XlpkjvaKvOvU', 1000088],
#    ['pgblKMCEuhUL', 'MdFemJMjtWks', 1000089],
#    ['TNCQDQrWapfJ', 'XLDYVpOfGWQs', 1000090],
#    ['YTliCaIuWCaq', 'styLDMdLPeqO', 1000091],
#    ['YbQJaWADdSBU', 'MgOsvbOBWgRO', 1000092],
#    ['UMzcEOajzuPi', 'ROTNmVdEJrdv', 1000093],
#    ['ZqXFYbXJdDra', 'UUKsMweSaYOJ', 1000094],
#    ['AkxdhUfzaopH', 'PTnuqMVIHcCa', 1000095],
#    ['yVeRwcaOszhU', 'JGMIixJSAFKp', 1000096],
#    ['toPQDlMNFENX', 'QBeuPWsibjSV', 1000097],
#    ['vJlbOEHppUcf', 'kOYqiZXHenwY', 1000098],
#    ['QDxCtArKXlXZ', 'hitIYfNIyQhz', 1000099],
#    ['fmrtbOEIwLUV', 'gYlqdYnSsYPd', 1000100]]])

# %%
def measure_time(students,store):
    s_copy = students.copy()
    random.shuffle(s_copy)
    start = time.time()
    for s in s_copy:
        store.add(s)
    add_time = time.time() - start
    random.shuffle(s_copy)
    start = time.time()
    for s in s_copy:
        store.get(s[2])
    get_time = (time.time() - start)/len(s_copy)
    random.shuffle(s_copy)
    start = time.time()
    for s in s_copy:
        store.delete(s[2])
    delete_time = time.time() - start
    return add_time,get_time,delete_time

# %%
def perform_test_single_store(store,X,Y):
    adds,gets,deletes=[],[],[]
    for y in Y:
        add,get,delete = measure_time(y,store)
        adds.append(add)
        gets.append(get)
        deletes.append(delete)
    return adds,gets,deletes

def plot_plot(X,Ys,labels,title):
    for i in range(len(Ys)):
        plt.plot(X,Ys[i],label=labels[i])
    plt.legend()
    plt.xlabel('Number of Elements')
    plt.ylabel('Time (s)')
    plt.title(title)
    plt.show()
    
    
def perform_test(stores,X,Y,labels):
    adds,gets,deletes =[],[],[]
    for store in stores:
        add,get,delete = perform_test_single_store(store,X,Y)
        adds.append(add)
        gets.append(get)
        deletes.append(delete)
    plot_plot(X,adds,labels,"Addition time")
    plot_plot(X,gets,labels,"Finding time")
    plot_plot(X,deletes,labels,"Deletion time")

# %%
X,Y = prepare_test_dataset(10000,100)
perform_test([SortedList(), Tree()],X,Y,["List","Tree"])

# %%
class AVLNode:
    def __init__(self,surname, firstname, index,left,right):
        self.left=left
        self.right=right
        self.surname = surname
        self.firstname = firstname
        self.index = index
        self.height = 1
    def print_me(self,level):
        print('-'.join(["-" for i in range(level)])+self.surname+self.firstname+str(self.index))
        if self.left:
            print('-'.join(["-" for i in range(level)])+'left')
            self.left.print_me(level+1)
        if self.right:
            print('-'.join(["-" for i in range(level)])+'right')
            self.right.print_me(level+1)

class AVLTree:
    def __init__(self):
        self.root = None
    def add(self,element):
        new_node = AVLNode(element[0],element[1],element[2],None,None);
        self.root = self.add_recursive(self.root,new_node)
        
    def add_recursive(self,root,new_node):
        if not root:
            return new_node
        if new_node.index < root.index:
            root.left = self.add_recursive(root.left,new_node)
        else:
            root.right = self.add_recursive(root.right,new_node)
        
        root.height = 1 + max(self.calculate_height(root.left),self.calculate_height(root.right))
        balance = self.calculate_balance(root)
        
        if balance > 1 and new_node.index  < root.left.index:
            return self.rotate_right(root)
        if balance < -1 and new_node.index > root.right.index:
            return self.rotate_left(root)
        if balance > 1 and new_node.index > root.left.index:
            root.left = self.rotate_left(root.left)
            return self.rotate_right(root)
        if balance < -1 and new_node.index < root.right.index:
            root.right = self.rotate_right(root.right)
            return self.rotate_left(root)
        return root
        
    def rotate_left(self,node):
        node2 = node.right
        temp = node2.left
        node2.left = node
        node.right = temp
        
        node.height = 1 + max(self.calculate_height(node.left),self.calculate_height(node.right))
        node2.height = 1 + max(self.calculate_height(node2.left),self.calculate_height(node2.right))
        return node2
    
    def rotate_right(self,node):
        node2 = node.left
        temp = node2.right
        node2.right = node
        node.left = temp
        
        node.height = 1 + max(self.calculate_height(node.left),self.calculate_height(node.right))
        node2.height = 1 + max(self.calculate_height(node2.left),self.calculate_height(node2.right))
        return node2
        
        
    def calculate_balance(self,node):
        if not node:
            return 0
        return self.calculate_height(node.left)-self.calculate_height(node.right)
    def calculate_height(self,node):
        if not node:
            return 0
        
        return node.height
        
    def get(self,index):
        cur_node = self.root
        while cur_node:
            if index < cur_node.index:
                cur_node = cur_node.left
            elif index > cur_node.index:
                cur_node = cur_node.right
            else:
                return cur_node
        raise BaseException("No node with this id")
    def print_all(self):
        if self.root:
            self.root.print_me(0)
        else:
            print("Empty tree")
    def count(self):
        if not self.root:
            return 0
        return self.root.count()

# %%
def measure_time_2(students,store):
    s_copy = students.copy()
    random.shuffle(s_copy)
    start = time.time()
    for s in s_copy:
        store.add(s)
    add_time = time.time() - start
    random.shuffle(s_copy)
    start = time.time()
    for s in s_copy:
        store.get(s[2])
    get_time = (time.time() - start)/len(s_copy)
    random.shuffle(s_copy)
    start = time.time()
    for s in s_copy:
        store.delete(s[2])
    delete_time = time.time() - start
    return add_time,get_time,delete_time

# %%
avl = AVLTree()
for i in [10,20,30,40,50,25,60,70,80,90,100,110]:
    avl.add(["a","a",i])
avl.print_all()
# Out:
# aa70
# left
# -aa30
# -left
# ---aa20
# ---left
# -----aa10
# ---right
# -----aa25
# -right
# ---aa50
# ---left
# -----aa40
# ---right
# -----aa60
# right
# -aa90
# -left
# ---aa80
# -right
# ---aa100
# ---right
# -----aa110

# %%
if self.root.index == index:
            if self.root.left and self.root.right:
                bigger_node = self.get_min_node(self.root.right)
                if not bigger_node is self.root.left:
                    bigger_node.left = self.root.left
                if not bigger_node is self.root.right:
                    bigger_node.right = self.root.right
                self.root = bigger_node
            elif self.root.left:
                self.root = self.root.left
            elif self.root.right:
                self.root = self.root.right
            else:
                self.root = None
            return
        parentNode = None
        node = self.root
        while True:
            if index < node.index:
                if node.left:
                    if index == node.left.index:#delete left node
                        if node.left.left and node.left.right:
                            bigger_node = self.get_min_node(node.left.right)
                            if not bigger_node is node.left.left:
                                bigger_node.left = node.left.left
                            if not bigger_node is node.left.right:
                                bigger_node.right = node.left.right
                            node.left = bigger_node
                        elif node.left.left:
                            node.left = node.left.left
                        elif node.left.right:
                            node.left = node.left.right
                        else:
                            node.left = None
                        break;
                    else:
                        node = node.left
                else:
                    raise BaseException("No node with this id")
            else:
                if node.right:
                    if index == node.right.index:#delete right node
                        if node.right.left and node.right.right:
                            bigger_node = self.get_min_node(node.right.right)
                            if not bigger_node is node.right.left:
                                bigger_node.left = node.right.left
                            if not bigger_node is node.right.right:
                                bigger_node.right = node.right.right
                            node.right = bigger_node
                        elif node.right.left:
                            node.right = node.right.left
                        elif node.right.right:
                            node.right = node.right.right
                        else:
                            node.right = None
                        break;
                    else:
                        node = node.right
                else:
                    raise BaseException("No node with this id")
